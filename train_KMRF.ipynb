# %% [markdown]
# # KMRF Model - Batch Training Notebook
#
# This notebook trains KMRF models across multiple assets in batch mode.
#
# **Output Structure:**
# ```
# saved_models/KMRF/
# ├── adapted_labels/
# │   ├── us_equity/
# │   ├── commodity/
# │   └── us_treasury/
# └── original_labels/
#     └── ...
# ```

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from pathlib import Path
from datetime import datetime
from typing import Dict, List, Optional
import traceback
import json

warnings.filterwarnings('ignore')

import kmrf as kmrf

# %matplotlib inline

# %% [markdown]
# ## Asset Lists
#
# Define the assets to train models for:

# %%
# US Equity Assets
us_equity_assets = [
    # Major Indices ETFs
    'SPDR S&P 500 ETF',  # SPY
    'Vanguard S&P 500 ETF',  # VOO
    'iShares Core S&P 500 ETF',  # IVV
    'Invesco QQQ Trust',  # QQQ
    'iShares Russell 2000 ETF',  # IWM
    'Vanguard Total Stock Market ETF',  # VTI
    
    # Sector ETFs (Select Sector SPDRs)
    'Energy Select Sector SPDR',  # XLE
    'Financial Select Sector SPDR',  # XLF
    'Utilities Select Sector SPDR',  # XLU
    'Industrial Select Sector SPDR',  # XLI
    'Health Care Select Sector SPDR',  # XLV
    'Technology Select Sector SPDR',  # XLK
    'Materials Select Sector SPDR',  # XLB
    'Consumer Discretionary Select Sector SPDR',  # XLY
    'Consumer Staples Select Sector SPDR',  # XLP
    
    # Style ETFs
    'iShares S&P 500 Growth ETF',  # IVW
    'iShares S&P 500 Value ETF',  # IVE
    'iShares Russell 1000 Growth ETF',  # IWF
    'iShares Russell 1000 Value ETF',  # IWD
]

# US Treasury Assets
us_treasury_assets = [
    'SPDR Bloomberg 1-3 Month T-Bill ETF',  # BIL
    'iShares 1-3 Year Treasury Bond ETF',  # SHY
    'iShares 7-10 Year Treasury Bond ETF',  # IEF
]

# International Equity ETFs
int_equity_assets = [
    'Vanguard Total International Stock ETF',  # VXUS
    'Vanguard FTSE Developed Markets ETF',  # VEA
    'Vanguard FTSE Emerging Markets ETF',  # VWO
    'Vanguard FTSE Europe ETF',  # VGK
    'Vanguard FTSE Pacific ETF',  # VPL
    'iShares China Large-Cap ETF',  # FXI
    'iShares MSCI Japan ETF',  # EWJ
    'iShares MSCI India ETF',  # INDA
]

# Commodity Assets
commodity_assets = [
    'Gold Futures',
    'Silver Futures',
    'Crude Oil WTI Futures',
    'Natural Gas Futures',
    'Copper Futures',
]

# Map asset classes to their asset lists
ASSET_GROUPS = {
    'us_equity': us_equity_assets,
    'us_treasury': us_treasury_assets,
    'int_equity': int_equity_assets,
    'commodity': commodity_assets,
}

# %% [markdown]
# ## *** Configuration ***
#
# Set batch training parameters:

# %%
# ============================================================================
# BATCH TRAINING CONFIGURATION
# ============================================================================

# Select which asset classes to train
ASSET_CLASSES_TO_TRAIN = ['us_equity']  # Options: 'us_equity', 'us_treasury', 'int_equity', 'commodity'

# Classification type
CLASSIFICATION_TYPE = 'original'  # 'original' (4 regimes) or 'adapted' (3 regimes)

# Feature selection
USE_BORUTA = True  # WARNING: Boruta is slow
BORUTA_MAX_ITER = 100  # Max iterations for Boruta

# Training/validation/test split dates
END_DATE = '20190101'  # Data up to this date for training
VALIDATION_START = '2019-04-01'
VALIDATION_END = '2019-09-30'
TEST_START = '2020-01-01'

# Other parameters
RANDOM_SEED = 1010
INCLUDE_MACRO = True  # Include macroeconomic features

# Error handling
CONTINUE_ON_ERROR = True  # If True, continue training other assets if one fails
SAVE_SUCCESSFUL_ONLY = True  # Only save models that trained successfully

# Verbose output
VERBOSE = True

# %% [markdown]
# ## Batch Training Function

# %%
def train_kmrf_batch(
    asset_names: List[str],
    asset_class: str,
    classification_type: str = 'adapted',
    end_date: str = '20190101',
    validation_start: str = '2019-04-01',
    validation_end: str = '2019-09-30',
    test_start: str = '2020-01-01',
    use_boruta: bool = False,
    boruta_params: Optional[Dict] = None,
    include_macro: bool = True,
    random_seed: int = 42,
    continue_on_error: bool = True,
    save_successful_only: bool = True,
    verbose: bool = True
) -> Dict[str, Dict]:
    """
    Train KMRF models for multiple assets in batch mode.
    
    Parameters
    ----------
    asset_names : List[str]
        List of asset names to train models for
    asset_class : str
        Asset class ('us_equity', 'us_treasury', 'int_equity', 'commodity')
    classification_type : str, default='adapted'
        Classification type ('original' or 'adapted')
    end_date : str
        Training data end date
    validation_start : str
        Validation period start date
    validation_end : str
        Validation period end date
    test_start : str
        Test period start date
    use_boruta : bool, default=False
        Whether to use Boruta feature selection
    boruta_params : dict, optional
        Parameters for Boruta (default: {'max_iter': 100})
    include_macro : bool, default=True
        Whether to include macroeconomic features
    random_seed : int, default=42
        Random seed for reproducibility
    continue_on_error : bool, default=True
        Whether to continue if one asset fails
    save_successful_only : bool, default=True
        Only save successfully trained models
    verbose : bool, default=True
        Print detailed progress
        
    Returns
    -------
    Dict[str, Dict]
        Dictionary with training results and metadata for each asset
    """
    
    if boruta_params is None:
        boruta_params = {'max_iter': 100}
    
    results = {}
    successful_models = []
    failed_models = []
    
    total_assets = len(asset_names)
    
    print(f"\n{'='*80}")
    print(f"BATCH TRAINING KMRF MODELS")
    print(f"{'='*80}")
    print(f"Asset Class: {asset_class}")
    print(f"Classification Type: {classification_type}")
    print(f"Total Assets: {total_assets}")
    print(f"Use Boruta: {use_boruta}")
    print(f"Include Macro: {include_macro}")
    print(f"Training Period: up to {end_date}")
    print(f"Validation: {validation_start} to {validation_end}")
    print(f"Test: {test_start} onwards")
    print(f"{'='*80}\n")
    
    for idx, asset_name in enumerate(asset_names, 1):
        print(f"\n{'='*80}")
        print(f"[{idx}/{total_assets}] Processing: {asset_name}")
        print(f"{'='*80}")
        
        start_time = datetime.now()
        
        try:
            # Initialize model
            if verbose:
                print(f"\n1. Initializing KMRF model...")
            
            model = kmrf.KMRF(
                asset_name=asset_name,
                asset_class=asset_class,
                end_date=end_date,
                use_ready_data=True,
                validation_start=validation_start,
                validation_end=validation_end,
                test_start=test_start,
                random_seed=random_seed,
                classification_type=classification_type
            )
            
            # Load data
            if verbose:
                print(f"2. Loading data...")
            data = model.load_data()
            features = model.get_features()
            
            if verbose:
                print(f"   Data shape: {data.shape}")
                print(f"   Features shape: {features.shape}")
            
            # Load labels
            if verbose:
                print(f"3. Loading KAMA+MSR labels...")
            model.load_kama_msr_labels()
            
            if classification_type == 'adapted':
                if verbose:
                    print(f"   Adapting to 3-class labels...")
                model.adapt_regime_labels()
            
            # Prepare training data
            if verbose:
                print(f"4. Preparing training data...")
                if use_boruta:
                    print(f"   Running Boruta feature selection (this may take 30+ minutes)...")
            
            X_train, y_train = model.prepare_training_data(
                include_macro=include_macro,
                select_features=use_boruta,
                boruta_params=boruta_params,
                split_data=True
            )
            
            if verbose:
                print(f"   Training samples: {len(X_train)}")
                print(f"   Features: {X_train.shape[1]}")
                if model.selected_features:
                    print(f"   Selected features: {len(model.selected_features)}")
            
            # Train model
            if verbose:
                print(f"5. Training Random Forest model...")
            
            model.fit(X_train, y_train)
            
            # Save model
            if verbose:
                print(f"6. Saving model...")
            
            model_path = model.save_model(boruta_used=use_boruta)
            
            # Record success
            end_time = datetime.now()
            duration = (end_time - start_time).total_seconds()
            
            results[asset_name] = {
                'status': 'success',
                'model_path': str(model_path),
                'n_features': X_train.shape[1],
                'n_selected_features': len(model.selected_features) if model.selected_features else None,
                'n_train_samples': len(X_train),
                'n_test_samples': len(model.X_test) if model.X_test is not None else None,
                'boruta_used': use_boruta,
                'duration_seconds': duration,
                'timestamp': datetime.now().isoformat()
            }
            
            successful_models.append(asset_name)
            
            print(f"\n✓ SUCCESS: {asset_name}")
            print(f"  Model saved to: {model_path}")
            print(f"  Training time: {duration/60:.1f} minutes")
            
        except Exception as e:
            # Record failure
            end_time = datetime.now()
            duration = (end_time - start_time).total_seconds()
            
            error_msg = str(e)
            error_trace = traceback.format_exc()
            
            results[asset_name] = {
                'status': 'failed',
                'error': error_msg,
                'error_trace': error_trace,
                'duration_seconds': duration,
                'timestamp': datetime.now().isoformat()
            }
            
            failed_models.append(asset_name)
            
            print(f"\n✗ FAILED: {asset_name}")
            print(f"  Error: {error_msg}")
            
            if verbose:
                print(f"\n  Full traceback:")
                print(error_trace)
            
            if not continue_on_error:
                print(f"\nStopping batch training due to error.")
                break
    
    # Print summary
    print(f"\n{'='*80}")
    print(f"BATCH TRAINING COMPLETE")
    print(f"{'='*80}")
    print(f"Total Assets: {total_assets}")
    print(f"Successful: {len(successful_models)}")
    print(f"Failed: {len(failed_models)}")
    
    if successful_models:
        print(f"\n✓ Successfully trained models:")
        for name in successful_models:
            duration = results[name]['duration_seconds']
            print(f"  - {name} ({duration/60:.1f} min)")
    
    if failed_models:
        print(f"\n✗ Failed models:")
        for name in failed_models:
            print(f"  - {name}: {results[name]['error']}")
    
    # Save training summary
    summary_dir = Path(f'saved_models/KMRF/{classification_type}_labels/{asset_class}')
    summary_dir.mkdir(parents=True, exist_ok=True)
    summary_path = summary_dir / f'training_summary_{end_date}.json'
    
    with open(summary_path, 'w') as f:
        json.dump(results, f, indent=2)
    
    print(f"\n✓ Training summary saved to: {summary_path}")
    print(f"{'='*80}\n")
    
    return results

# %% [markdown]
# ## Run Batch Training
#
# Execute this cell to train models for all configured asset classes:

# %%
# Run batch training for each selected asset class
all_results = {}

for asset_class in ASSET_CLASSES_TO_TRAIN:
    asset_names = ASSET_GROUPS.get(asset_class, [])
    
    if not asset_names:
        print(f"Warning: No assets defined for class '{asset_class}'. Skipping.")
        continue
    
    print(f"\n{'#'*80}")
    print(f"# TRAINING ASSET CLASS: {asset_class.upper()}")
    print(f"# Assets: {len(asset_names)}")
    print(f"{'#'*80}")
    
    results = train_kmrf_batch(
        asset_names=asset_names,
        asset_class=asset_class,
        classification_type=CLASSIFICATION_TYPE,
        end_date=END_DATE,
        validation_start=VALIDATION_START,
        validation_end=VALIDATION_END,
        test_start=TEST_START,
        use_boruta=USE_BORUTA,
        boruta_params={'max_iter': BORUTA_MAX_ITER},
        include_macro=INCLUDE_MACRO,
        random_seed=RANDOM_SEED,
        continue_on_error=CONTINUE_ON_ERROR,
        save_successful_only=SAVE_SUCCESSFUL_ONLY,
        verbose=VERBOSE
    )
    
    all_results[asset_class] = results

print(f"\n{'#'*80}")
print(f"# ALL BATCH TRAINING COMPLETE")
print(f"{'#'*80}")

# Overall summary
total_attempted = sum(len(results) for results in all_results.values())
total_successful = sum(
    sum(1 for r in results.values() if r['status'] == 'success')
    for results in all_results.values()
)
total_failed = total_attempted - total_successful

print(f"\nOverall Results:")
print(f"  Total Assets Attempted: {total_attempted}")
print(f"  Successful: {total_successful}")
print(f"  Failed: {total_failed}")
print(f"  Success Rate: {100*total_successful/total_attempted:.1f}%")
# Out:
# ################################################################################
# # TRAINING ASSET CLASS: US_EQUITY
# # Assets: 19
# ################################################################################
#
# ================================================================================
# BATCH TRAINING KMRF MODELS
# ================================================================================
# Asset Class: us_equity
# Classification Type: original
# Total Assets: 19
# Use Boruta: True
# Include Macro: True
# Training Period: up to 20190101
# Validation: 2019-04-01 to 2019-09-30
# Test: 2020-01-01 onwards
# ================================================================================
#
#
# ================================================================================
# [1/19] Processing: SPDR S&P 500 ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: SPDR S&P 500 ETF
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
# Loaded data for: SPDR S&P 500 ETF
#   Rows: 9022
#   Columns: 95
#   Date range: 1990-01-02 00:00:00 to 2025-10-24 00:00:00
#
# Extracting pre-computed features for SPDR S&P 500 ETF...
#   Features shape: (9022, 95)
#    Data shape: (9022, 95)
#    Features shape: (9022, 95)
# 3. Loading KAMA+MSR labels...
#
# ================================================================================
# LOADING KAMA+MSR LABELS FOR SPDR S&P 500 ETF
# ================================================================================
# Model directory: saved_models/KAMA_MSR/us_equity/20190101
# Loading from: SPDR S&P 500 ETF_KAMA-MSR_4-regimes.pkl
# ✓ Loaded labels for: SPDR S&P 500 ETF
#   Label date range: 1995-01-04 00:00:00 to 2018-12-31 00:00:00
#   Total periods: 6041
#
#   Original 4-regime distribution:
#     0 -   LV Bullish:  4560 ( 75.7%)
#     1 -   LV Bearish:  1138 ( 18.9%)
#     2 -   HV Bullish:    26 (  0.4%)
#     3 -   HV Bearish:   299 (  5.0%)
# ================================================================================
# 4. Preparing training data...
#    Running Boruta feature selection (this may take 30+ minutes)...
#
# ================================================================================
# PREPARING TRAINING DATA FOR SPDR S&P 500 ETF
# ================================================================================
#
# Step 1: Technical Features
#   Features Shape: (9022, 95)
#
# Step 2: Loading Macroeconomic Data
#
# Loading macroeconomic data from: data/ready/macro_data_all.csv
# Aligned macro data to features index
# Macro data shape: (9022, 19)
# Macro indicators: 19
#   Combined shape: (9022, 114)
#
# Step 3: Using Original 4-Regime Labels
#   (LV Bullish=0, LV Bearish=1, HV Bullish=2, HV Bearish=3)
#   Labels Shape: (6041,)
#
# Step 4: Cleaning Features - start when labels exist
#   Features date range: 1995-01-04 00:00:00 to 2025-10-24 00:00:00
#   Labels date range: 1995-01-04 00:00:00 to 2018-12-31 00:00:00
#   Dropping 1 features with >50% NaN values
#   Features ready across full date range
#
# Step 5: Splitting Data
#   Train/Validation/Test Split:
#     Training   : Before 2019-04-01
#     Validation : 2019-04-01 to 2019-09-30
#     Test       : 2020-01-01 to End
#
#   Split sizes:
#     Training   : 6041 samples with labels (1995-01-04 to 2018-12-31)
#     Validation : 127 samples (features only, no labels) (2019-04-01 to 2019-09-30)
#     Test       : 1463 samples (features only, no labels) (2020-01-02 to 2025-10-24)
#
#   Applying Boruta feature selection on training data...
#
# ================================================================================
# BORUTA FEATURE SELECTION
# ================================================================================
# Initial features: 113
# Samples: 6041
# Max iterations: 100
#
# Handling missing values...
#   Removed 18 samples with missing values
#   Clean dataset: 6023 samples, 113 features
# Fitting Boruta...
# Loaded data for: SPDR S&P 500 ETF
#   Rows: 9022
#   Columns: 95
#   Date range: 1990-01-02 00:00:00 to 2025-10-24 00:00:00
#
# Extracting pre-computed features for SPDR S&P 500 ETF...
#   Features shape: (9022, 95)
#    Data shape: (9022, 95)
#    Features shape: (9022, 95)
# 3. Loading KAMA+MSR labels...
#
# ================================================================================
# LOADING KAMA+MSR LABELS FOR SPDR S&P 500 ETF
# ================================================================================
# Model directory: saved_models/KAMA_MSR/us_equity/20190101
# Loading from: SPDR S&P 500 ETF_KAMA-MSR_4-regimes.pkl
# ✓ Loaded labels for: SPDR S&P 500 ETF
#   Label date range: 1995-01-04 00:00:00 to 2018-12-31 00:00:00
#   Total periods: 6041
#
#   Original 4-regime distribution:
#     0 -   LV Bullish:  4560 ( 75.7%)
#     1 -   LV Bearish:  1138 ( 18.9%)
#     2 -   HV Bullish:    26 (  0.4%)
#     3 -   HV Bearish:   299 (  5.0%)
# ================================================================================
# 4. Preparing training data...
#    Running Boruta feature selection (this may take 30+ minutes)...
#
# ================================================================================
# PREPARING TRAINING DATA FOR SPDR S&P 500 ETF
# ================================================================================
#
# Step 1: Technical Features
#   Features Shape: (9022, 95)
#
# Step 2: Loading Macroeconomic Data
#
# Loading macroeconomic data from: data/ready/macro_data_all.csv
# Aligned macro data to features index
# Macro data shape: (9022, 19)
# Macro indicators: 19
#   Combined shape: (9022, 114)
#
# Step 3: Using Original 4-Regime Labels
#   (LV Bullish=0, LV Bearish=1, HV Bullish=2, HV Bearish=3)
#   Labels Shape: (6041,)
#
# Step 4: Cleaning Features - start when labels exist
#   Features date range: 1995-01-04 00:00:00 to 2025-10-24 00:00:00
#   Labels date range: 1995-01-04 00:00:00 to 2018-12-31 00:00:00
#   Dropping 1 features with >50% NaN values
#   Features ready across full date range
#
# Step 5: Splitting Data
#   Train/Validation/Test Split:
#     Training   : Before 2019-04-01
#     Validation : 2019-04-01 to 2019-09-30
#     Test       : 2020-01-01 to End
#
#   Split sizes:
#     Training   : 6041 samples with labels (1995-01-04 to 2018-12-31)
#     Validation : 127 samples (features only, no labels) (2019-04-01 to 2019-09-30)
#     Test       : 1463 samples (features only, no labels) (2020-01-02 to 2025-10-24)
#
#   Applying Boruta feature selection on training data...
#
# ================================================================================
# BORUTA FEATURE SELECTION
# ================================================================================
# Initial features: 113
# Samples: 6041
# Max iterations: 100
#
# Handling missing values...
#   Removed 18 samples with missing values
#   Clean dataset: 6023 samples, 113 features
# Fitting Boruta...
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	87
# Tentative: 	26
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	87
# Tentative: 	26
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	87
# Tentative: 	26
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	87
# Tentative: 	26
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	87
# Tentative: 	26
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	87
# Tentative: 	26
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	87
# Tentative: 	24
# Rejected: 	2
# Iteration: 	13 / 100
# Confirmed: 	87
# Tentative: 	24
# Rejected: 	2
# Iteration: 	14 / 100
# Confirmed: 	87
# Tentative: 	24
# Rejected: 	2
# Iteration: 	14 / 100
# Confirmed: 	87
# Tentative: 	24
# Rejected: 	2
# Iteration: 	15 / 100
# Confirmed: 	92
# Tentative: 	19
# Rejected: 	2
# Iteration: 	15 / 100
# Confirmed: 	92
# Tentative: 	19
# Rejected: 	2
# Iteration: 	16 / 100
# Confirmed: 	92
# Tentative: 	19
# Rejected: 	2
# Iteration: 	16 / 100
# Confirmed: 	92
# Tentative: 	19
# Rejected: 	2
# Iteration: 	17 / 100
# Confirmed: 	92
# Tentative: 	19
# Rejected: 	2
# Iteration: 	17 / 100
# Confirmed: 	92
# Tentative: 	19
# Rejected: 	2
# Iteration: 	18 / 100
# Confirmed: 	92
# Tentative: 	19
# Rejected: 	2
# Iteration: 	18 / 100
# Confirmed: 	92
# Tentative: 	19
# Rejected: 	2
# Iteration: 	19 / 100
# Confirmed: 	95
# Tentative: 	16
# Rejected: 	2
# Iteration: 	19 / 100
# Confirmed: 	95
# Tentative: 	16
# Rejected: 	2
# Iteration: 	20 / 100
# Confirmed: 	95
# Tentative: 	16
# Rejected: 	2
# Iteration: 	20 / 100
# Confirmed: 	95
# Tentative: 	16
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	95
# Tentative: 	16
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	95
# Tentative: 	16
# Rejected: 	2
# Iteration: 	22 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	22 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	23 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	23 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	24 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	24 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	25 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	25 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	26 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	26 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	27 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	27 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	28 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	28 / 100
# Confirmed: 	98
# Tentative: 	12
# Rejected: 	3
# Iteration: 	29 / 100
# Confirmed: 	99
# Tentative: 	11
# Rejected: 	3
# Iteration: 	29 / 100
# Confirmed: 	99
# Tentative: 	11
# Rejected: 	3
# Iteration: 	30 / 100
# Confirmed: 	99
# Tentative: 	11
# Rejected: 	3
# Iteration: 	30 / 100
# Confirmed: 	99
# Tentative: 	11
# Rejected: 	3
# Iteration: 	31 / 100
# Confirmed: 	99
# Tentative: 	11
# Rejected: 	3
# Iteration: 	31 / 100
# Confirmed: 	99
# Tentative: 	11
# Rejected: 	3
# Iteration: 	32 / 100
# Confirmed: 	100
# Tentative: 	10
# Rejected: 	3
# Iteration: 	32 / 100
# Confirmed: 	100
# Tentative: 	10
# Rejected: 	3
# Iteration: 	33 / 100
# Confirmed: 	100
# Tentative: 	10
# Rejected: 	3
# Iteration: 	33 / 100
# Confirmed: 	100
# Tentative: 	10
# Rejected: 	3
# Iteration: 	34 / 100
# Confirmed: 	100
# Tentative: 	10
# Rejected: 	3
# Iteration: 	34 / 100
# Confirmed: 	100
# Tentative: 	10
# Rejected: 	3
# Iteration: 	35 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	35 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	36 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	36 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	37 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	37 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	38 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	38 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	39 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	39 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	40 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	40 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	41 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	41 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	42 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	42 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	43 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	43 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	44 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	44 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	45 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	45 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	46 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	46 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	47 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	47 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	48 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	48 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	49 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	49 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	50 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	50 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	51 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	51 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	52 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	52 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	53 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	53 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	54 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	54 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	55 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	55 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	56 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	56 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	57 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	57 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	58 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	58 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	59 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	59 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	60 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	60 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	61 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	61 / 100
# Confirmed: 	102
# Tentative: 	8
# Rejected: 	3
# Iteration: 	62 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	62 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	63 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	63 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	64 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	64 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	65 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	65 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	66 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	66 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	67 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	67 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	68 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	68 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	69 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	69 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	70 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	70 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	71 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	71 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	72 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	72 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	73 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	73 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	74 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	74 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	75 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	75 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	76 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	76 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	77 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	77 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	78 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	78 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	79 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	79 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	80 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	80 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	81 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	81 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	82 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	82 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	83 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	83 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	84 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	84 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	85 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	85 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	86 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	86 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	87 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	87 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	88 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	88 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	89 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	89 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	90 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	90 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	91 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	91 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	92 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	92 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	93 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	93 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	94 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	94 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	95 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	95 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	96 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	96 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	97 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	97 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	98 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	98 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
# Iteration: 	99 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	102
# Tentative: 	5
# Rejected: 	6
#
# ================================================================================
# BORUTA RESULTS
# ================================================================================
# Selected features: 102
# Rejected features: 11
# Tentative features: 5
#
# Top 20 selected features:
#    1. ema_ratio_120d_lag1d                               (importance: 0.050775)
#    2. log_ret_60d_lag1d                                  (importance: 0.038066)
#    3. momentum_60d_lag1d                                 (importance: 0.037542)
#    4. skew_20d_lag1d                                     (importance: 0.034189)
#    5. momentum_120d_lag1d                                (importance: 0.033180)
#    6. log_ret_120d_lag1d                                 (importance: 0.032204)
#    7. ("Moody's Seasoned BAA Corporate Bond Yield (DBAA) lag1d", 'Percent') (importance: 0.028816)
#    8. parkinson_vol_252d_lag1d                           (importance: 0.026763)
#    9. ema_ratio_60d_lag1d                                (importance: 0.025382)
#   10. vol_252d_lag1d                                     (importance: 0.023407)
#   11. skew_120d_lag1d                                    (importance: 0.023388)
#   12. macd_lag1d                                         (importance: 0.019997)
#   13. kurt_20d_lag1d                                     (importance: 0.019761)
#   14. skew_60d_lag1d                                     (importance: 0.019564)
#   15. macd_signal_lag1d                                  (importance: 0.019425)
#   16. log_ret_252d_lag1d                                 (importance: 0.019320)
#   17. log_ret_20d_lag1d                                  (importance: 0.015946)
#   18. gk_vol_252d_lag1d                                  (importance: 0.015453)
#   19. daily_range_lag1d                                  (importance: 0.015292)
#   20. gk_vol_20d_lag1d                                   (importance: 0.015000)
# Iteration: 	99 / 100
# Confirmed: 	102
# Tentative: 	7
# Rejected: 	4
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	102
# Tentative: 	5
# Rejected: 	6
#
# ================================================================================
# BORUTA RESULTS
# ================================================================================
# Selected features: 102
# Rejected features: 11
# Tentative features: 5
#
# Top 20 selected features:
#    1. ema_ratio_120d_lag1d                               (importance: 0.050775)
#    2. log_ret_60d_lag1d                                  (importance: 0.038066)
#    3. momentum_60d_lag1d                                 (importance: 0.037542)
#    4. skew_20d_lag1d                                     (importance: 0.034189)
#    5. momentum_120d_lag1d                                (importance: 0.033180)
#    6. log_ret_120d_lag1d                                 (importance: 0.032204)
#    7. ("Moody's Seasoned BAA Corporate Bond Yield (DBAA) lag1d", 'Percent') (importance: 0.028816)
#    8. parkinson_vol_252d_lag1d                           (importance: 0.026763)
#    9. ema_ratio_60d_lag1d                                (importance: 0.025382)
#   10. vol_252d_lag1d                                     (importance: 0.023407)
#   11. skew_120d_lag1d                                    (importance: 0.023388)
#   12. macd_lag1d                                         (importance: 0.019997)
#   13. kurt_20d_lag1d                                     (importance: 0.019761)
#   14. skew_60d_lag1d                                     (importance: 0.019564)
#   15. macd_signal_lag1d                                  (importance: 0.019425)
#   16. log_ret_252d_lag1d                                 (importance: 0.019320)
#   17. log_ret_20d_lag1d                                  (importance: 0.015946)
#   18. gk_vol_252d_lag1d                                  (importance: 0.015453)
#   19. daily_range_lag1d                                  (importance: 0.015292)
#   20. gk_vol_20d_lag1d                                   (importance: 0.015000)
#   Feature selection applied to all splits
#
#   Label distribution:
#     Training (with labels):
#        LV_Bull ( 0):  4560 ( 75.5%)
#        LV_Bear ( 1):  1138 ( 18.8%)
#        HV_Bull ( 2):    26 (  0.4%)
#        HV_Bear ( 3):   299 (  4.9%)
#     Validation: No labels (prediction only)
#     Test: No labels (prediction only)
#
# ================================================================================
# DATA PREPARATION COMPLETE
# ================================================================================
#
# Note: Validation and test sets have features only.
#       Use trained model to generate predictions on these sets.
#    Training samples: 6041
#    Features: 102
#    Selected features: 102
# 5. Training Random Forest model...
#
# ================================================================================
# TRAINING RANDOM FOREST CLASSIFIER
# ================================================================================
# RF Parameters:
#   n_estimators: 220
#   max_depth: 13
#   min_samples_split: 76
#   min_samples_leaf: 95
#   max_samples: 0.36
#   max_features: 0.25
#   min_weight_fraction_leaf: 0.045
#   random_state: 1010
#   n_jobs: -1
#
# Training samples: 6023
# Features: 102
# Date range: 1995-01-30 00:00:00 to 2018-12-31 00:00:00
#
# Fitting Random Forest...
#   Feature selection applied to all splits
#
#   Label distribution:
#     Training (with labels):
#        LV_Bull ( 0):  4560 ( 75.5%)
#        LV_Bear ( 1):  1138 ( 18.8%)
#        HV_Bull ( 2):    26 (  0.4%)
#        HV_Bear ( 3):   299 (  4.9%)
#     Validation: No labels (prediction only)
#     Test: No labels (prediction only)
#
# ================================================================================
# DATA PREPARATION COMPLETE
# ================================================================================
#
# Note: Validation and test sets have features only.
#       Use trained model to generate predictions on these sets.
#    Training samples: 6041
#    Features: 102
#    Selected features: 102
# 5. Training Random Forest model...
#
# ================================================================================
# TRAINING RANDOM FOREST CLASSIFIER
# ================================================================================
# RF Parameters:
#   n_estimators: 220
#   max_depth: 13
#   min_samples_split: 76
#   min_samples_leaf: 95
#   max_samples: 0.36
#   max_features: 0.25
#   min_weight_fraction_leaf: 0.045
#   random_state: 1010
#   n_jobs: -1
#
# Training samples: 6023
# Features: 102
# Date range: 1995-01-30 00:00:00 to 2018-12-31 00:00:00
#
# Fitting Random Forest...
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Model ready for prediction
# 6. Saving model...
#
# Saving model to: saved_models/KMRF/original_labels/us_equity/KMRF_SPDR-S&P-500-ETF_20190101_boruta.pkl
#   Asset: SPDR S&P 500 ETF
#   Classification type: original
#   Features: 102
#   Training samples: 6041
# ✓ Model saved successfully
#
# ✓ SUCCESS: SPDR S&P 500 ETF
#   Model saved to: saved_models/KMRF/original_labels/us_equity/KMRF_SPDR-S&P-500-ETF_20190101_boruta.pkl
#   Training time: 6.6 minutes
#
# ================================================================================
# [2/19] Processing: Vanguard S&P 500 ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: Vanguard S&P 500 ETF
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Model ready for prediction
# 6. Saving model...
#
# Saving model to: saved_models/KMRF/original_labels/us_equity/KMRF_SPDR-S&P-500-ETF_20190101_boruta.pkl
#   Asset: SPDR S&P 500 ETF
#   Classification type: original
#   Features: 102
#   Training samples: 6041
# ✓ Model saved successfully
#
# ✓ SUCCESS: SPDR S&P 500 ETF
#   Model saved to: saved_models/KMRF/original_labels/us_equity/KMRF_SPDR-S&P-500-ETF_20190101_boruta.pkl
#   Training time: 6.6 minutes
#
# ================================================================================
# [2/19] Processing: Vanguard S&P 500 ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: Vanguard S&P 500 ETF
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
#
# ✗ FAILED: Vanguard S&P 500 ETF
#   Error: Asset 'Vanguard S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#   Full traceback:
# Traceback (most recent call last):
#   File "/var/folders/gw/n9n80qx50dqb3p299fjcnkzc0000gn/T/ipykernel_42532/2053907266.py", line 106, in train_kmrf_batch
#     data = model.load_data()
#   File "/Users/jessegoodman/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/kmrf.py", line 203, in load_data
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Asset 'Vanguard S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#
# ================================================================================
# [3/19] Processing: iShares Core S&P 500 ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: iShares Core S&P 500 ETF
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
#
# ✗ FAILED: Vanguard S&P 500 ETF
#   Error: Asset 'Vanguard S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#   Full traceback:
# Traceback (most recent call last):
#   File "/var/folders/gw/n9n80qx50dqb3p299fjcnkzc0000gn/T/ipykernel_42532/2053907266.py", line 106, in train_kmrf_batch
#     data = model.load_data()
#   File "/Users/jessegoodman/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/kmrf.py", line 203, in load_data
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Asset 'Vanguard S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#
# ================================================================================
# [3/19] Processing: iShares Core S&P 500 ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: iShares Core S&P 500 ETF
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
#
# ✗ FAILED: iShares Core S&P 500 ETF
#   Error: Asset 'iShares Core S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#   Full traceback:
# Traceback (most recent call last):
#   File "/var/folders/gw/n9n80qx50dqb3p299fjcnkzc0000gn/T/ipykernel_42532/2053907266.py", line 106, in train_kmrf_batch
#     data = model.load_data()
#   File "/Users/jessegoodman/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/kmrf.py", line 203, in load_data
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Asset 'iShares Core S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#
# ================================================================================
# [4/19] Processing: Invesco QQQ Trust
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: Invesco QQQ Trust
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
#
# ✗ FAILED: iShares Core S&P 500 ETF
#   Error: Asset 'iShares Core S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#   Full traceback:
# Traceback (most recent call last):
#   File "/var/folders/gw/n9n80qx50dqb3p299fjcnkzc0000gn/T/ipykernel_42532/2053907266.py", line 106, in train_kmrf_batch
#     data = model.load_data()
#   File "/Users/jessegoodman/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/kmrf.py", line 203, in load_data
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Asset 'iShares Core S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#
# ================================================================================
# [4/19] Processing: Invesco QQQ Trust
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: Invesco QQQ Trust
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
# Loaded data for: Invesco QQQ Trust
#   Rows: 9022
#   Columns: 95
#   Date range: 1990-01-02 00:00:00 to 2025-10-24 00:00:00
#
# Extracting pre-computed features for Invesco QQQ Trust...
#   Features shape: (9022, 95)
#    Data shape: (9022, 95)
#    Features shape: (9022, 95)
# 3. Loading KAMA+MSR labels...
#
# ================================================================================
# LOADING KAMA+MSR LABELS FOR Invesco QQQ Trust
# ================================================================================
# Model directory: saved_models/KAMA_MSR/us_equity/20190101
# Loading from: Invesco QQQ Trust_KAMA-MSR_4-regimes.pkl
# ✓ Loaded labels for: Invesco QQQ Trust
#   Label date range: 1999-03-11 00:00:00 to 2018-12-31 00:00:00
#   Total periods: 4985
#
#   Original 4-regime distribution:
#     0 -   LV Bullish:  3403 ( 68.6%)
#     1 -   LV Bearish:   552 ( 11.1%)
#     2 -   HV Bullish:   299 (  6.0%)
#     3 -   HV Bearish:   708 ( 14.3%)
# ================================================================================
# 4. Preparing training data...
#    Running Boruta feature selection (this may take 30+ minutes)...
#
# ================================================================================
# PREPARING TRAINING DATA FOR Invesco QQQ Trust
# ================================================================================
#
# Step 1: Technical Features
#   Features Shape: (9022, 95)
#
# Step 2: Loading Macroeconomic Data
#
# Loading macroeconomic data from: data/ready/macro_data_all.csv
# Aligned macro data to features index
# Macro data shape: (9022, 19)
# Macro indicators: 19
#   Combined shape: (9022, 114)
#
# Step 3: Using Original 4-Regime Labels
#   (LV Bullish=0, LV Bearish=1, HV Bullish=2, HV Bearish=3)
#   Labels Shape: (4985,)
#
# Step 4: Cleaning Features - start when labels exist
#   Features date range: 1999-03-11 00:00:00 to 2025-10-24 00:00:00
#   Labels date range: 1999-03-11 00:00:00 to 2018-12-31 00:00:00
#   Dropping 1 features with >50% NaN values
#   Features ready across full date range
#
# Step 5: Splitting Data
#   Train/Validation/Test Split:
#     Training   : Before 2019-04-01
#     Validation : 2019-04-01 to 2019-09-30
#     Test       : 2020-01-01 to End
#
#   Split sizes:
#     Training   : 4985 samples with labels (1999-03-11 to 2018-12-31)
#     Validation : 127 samples (features only, no labels) (2019-04-01 to 2019-09-30)
#     Test       : 1463 samples (features only, no labels) (2020-01-02 to 2025-10-24)
#
#   Applying Boruta feature selection on training data...
#
# ================================================================================
# BORUTA FEATURE SELECTION
# ================================================================================
# Initial features: 113
# Samples: 4985
# Max iterations: 100
#
# Handling missing values...
#   Removed 23 samples with missing values
#   Clean dataset: 4962 samples, 113 features
# Fitting Boruta...
# Loaded data for: Invesco QQQ Trust
#   Rows: 9022
#   Columns: 95
#   Date range: 1990-01-02 00:00:00 to 2025-10-24 00:00:00
#
# Extracting pre-computed features for Invesco QQQ Trust...
#   Features shape: (9022, 95)
#    Data shape: (9022, 95)
#    Features shape: (9022, 95)
# 3. Loading KAMA+MSR labels...
#
# ================================================================================
# LOADING KAMA+MSR LABELS FOR Invesco QQQ Trust
# ================================================================================
# Model directory: saved_models/KAMA_MSR/us_equity/20190101
# Loading from: Invesco QQQ Trust_KAMA-MSR_4-regimes.pkl
# ✓ Loaded labels for: Invesco QQQ Trust
#   Label date range: 1999-03-11 00:00:00 to 2018-12-31 00:00:00
#   Total periods: 4985
#
#   Original 4-regime distribution:
#     0 -   LV Bullish:  3403 ( 68.6%)
#     1 -   LV Bearish:   552 ( 11.1%)
#     2 -   HV Bullish:   299 (  6.0%)
#     3 -   HV Bearish:   708 ( 14.3%)
# ================================================================================
# 4. Preparing training data...
#    Running Boruta feature selection (this may take 30+ minutes)...
#
# ================================================================================
# PREPARING TRAINING DATA FOR Invesco QQQ Trust
# ================================================================================
#
# Step 1: Technical Features
#   Features Shape: (9022, 95)
#
# Step 2: Loading Macroeconomic Data
#
# Loading macroeconomic data from: data/ready/macro_data_all.csv
# Aligned macro data to features index
# Macro data shape: (9022, 19)
# Macro indicators: 19
#   Combined shape: (9022, 114)
#
# Step 3: Using Original 4-Regime Labels
#   (LV Bullish=0, LV Bearish=1, HV Bullish=2, HV Bearish=3)
#   Labels Shape: (4985,)
#
# Step 4: Cleaning Features - start when labels exist
#   Features date range: 1999-03-11 00:00:00 to 2025-10-24 00:00:00
#   Labels date range: 1999-03-11 00:00:00 to 2018-12-31 00:00:00
#   Dropping 1 features with >50% NaN values
#   Features ready across full date range
#
# Step 5: Splitting Data
#   Train/Validation/Test Split:
#     Training   : Before 2019-04-01
#     Validation : 2019-04-01 to 2019-09-30
#     Test       : 2020-01-01 to End
#
#   Split sizes:
#     Training   : 4985 samples with labels (1999-03-11 to 2018-12-31)
#     Validation : 127 samples (features only, no labels) (2019-04-01 to 2019-09-30)
#     Test       : 1463 samples (features only, no labels) (2020-01-02 to 2025-10-24)
#
#   Applying Boruta feature selection on training data...
#
# ================================================================================
# BORUTA FEATURE SELECTION
# ================================================================================
# Initial features: 113
# Samples: 4985
# Max iterations: 100
#
# Handling missing values...
#   Removed 23 samples with missing values
#   Clean dataset: 4962 samples, 113 features
# Fitting Boruta...
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	102
# Tentative: 	11
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	102
# Tentative: 	11
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	102
# Tentative: 	11
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	102
# Tentative: 	11
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	102
# Tentative: 	11
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	102
# Tentative: 	11
# Rejected: 	0
# Iteration: 	13 / 100
# Confirmed: 	102
# Tentative: 	9
# Rejected: 	2
# Iteration: 	13 / 100
# Confirmed: 	102
# Tentative: 	9
# Rejected: 	2
# Iteration: 	14 / 100
# Confirmed: 	102
# Tentative: 	9
# Rejected: 	2
# Iteration: 	14 / 100
# Confirmed: 	102
# Tentative: 	9
# Rejected: 	2
# Iteration: 	15 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	15 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	16 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	16 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	17 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	17 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	18 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	18 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	19 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	19 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	20 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	20 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	21 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	22 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	22 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	23 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	23 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	24 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	24 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	25 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	25 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	26 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	26 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	27 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	27 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	28 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	28 / 100
# Confirmed: 	107
# Tentative: 	4
# Rejected: 	2
# Iteration: 	29 / 100
# Confirmed: 	108
# Tentative: 	3
# Rejected: 	2
# Iteration: 	29 / 100
# Confirmed: 	108
# Tentative: 	3
# Rejected: 	2
# Iteration: 	30 / 100
# Confirmed: 	108
# Tentative: 	3
# Rejected: 	2
# Iteration: 	30 / 100
# Confirmed: 	108
# Tentative: 	3
# Rejected: 	2
# Iteration: 	31 / 100
# Confirmed: 	108
# Tentative: 	3
# Rejected: 	2
# Iteration: 	31 / 100
# Confirmed: 	108
# Tentative: 	3
# Rejected: 	2
# Iteration: 	32 / 100
# Confirmed: 	108
# Tentative: 	3
# Rejected: 	2
# Iteration: 	32 / 100
# Confirmed: 	108
# Tentative: 	3
# Rejected: 	2
# Iteration: 	33 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	33 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	34 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	34 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	35 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	35 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	36 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	36 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	37 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	37 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	38 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	38 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	39 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	39 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	40 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	40 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	41 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	41 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	42 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	42 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	43 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	43 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	44 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	44 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	45 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	45 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	46 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	46 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	47 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	47 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	48 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	48 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	49 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	49 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	50 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	50 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	51 / 100
# Confirmed: 	108
# Tentative: 	1
# Rejected: 	4
# Iteration: 	51 / 100
# ...
# TRAINING RANDOM FOREST CLASSIFIER
# ================================================================================
# RF Parameters:
#   n_estimators: 220
#   max_depth: 13
#   min_samples_split: 76
#   min_samples_leaf: 95
#   max_samples: 0.36
#   max_features: 0.25
#   min_weight_fraction_leaf: 0.045
#   random_state: 1010
#   n_jobs: -1
#
# Training samples: 4652
# Features: 111
# Date range: 2000-07-05 00:00:00 to 2018-12-31 00:00:00
#
# Fitting Random Forest...
#
# Training samples: 4652
# Features: 111
# Date range: 2000-07-05 00:00:00 to 2018-12-31 00:00:00
#
# Fitting Random Forest...
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Model ready for prediction
# 6. Saving model...
#
# Saving model to: saved_models/KMRF/original_labels/us_equity/KMRF_iShares-S&P-500-Value-ETF_20190101_boruta.pkl
#   Asset: iShares S&P 500 Value ETF
#   Classification type: original
#   Features: 111
#   Training samples: 4677
# ✓ Model saved successfully
#
# ✓ SUCCESS: iShares S&P 500 Value ETF
#   Model saved to: saved_models/KMRF/original_labels/us_equity/KMRF_iShares-S&P-500-Value-ETF_20190101_boruta.pkl
#   Training time: 3.1 minutes
#
# ================================================================================
# [18/19] Processing: iShares Russell 1000 Growth ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: iShares Russell 1000 Growth ETF
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Model ready for prediction
# 6. Saving model...
#
# Saving model to: saved_models/KMRF/original_labels/us_equity/KMRF_iShares-S&P-500-Value-ETF_20190101_boruta.pkl
#   Asset: iShares S&P 500 Value ETF
#   Classification type: original
#   Features: 111
#   Training samples: 4677
# ✓ Model saved successfully
#
# ✓ SUCCESS: iShares S&P 500 Value ETF
#   Model saved to: saved_models/KMRF/original_labels/us_equity/KMRF_iShares-S&P-500-Value-ETF_20190101_boruta.pkl
#   Training time: 3.1 minutes
#
# ================================================================================
# [18/19] Processing: iShares Russell 1000 Growth ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: iShares Russell 1000 Growth ETF
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
#
# ✗ FAILED: iShares Russell 1000 Growth ETF
#   Error: Asset 'iShares Russell 1000 Growth ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#   Full traceback:
# Traceback (most recent call last):
#   File "/var/folders/gw/n9n80qx50dqb3p299fjcnkzc0000gn/T/ipykernel_42532/2053907266.py", line 106, in train_kmrf_batch
#     data = model.load_data()
#   File "/Users/jessegoodman/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/kmrf.py", line 203, in load_data
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Asset 'iShares Russell 1000 Growth ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#
# ================================================================================
# [19/19] Processing: iShares Russell 1000 Value ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: iShares Russell 1000 Value ETF
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
#
# ✗ FAILED: iShares Russell 1000 Growth ETF
#   Error: Asset 'iShares Russell 1000 Growth ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#   Full traceback:
# Traceback (most recent call last):
#   File "/var/folders/gw/n9n80qx50dqb3p299fjcnkzc0000gn/T/ipykernel_42532/2053907266.py", line 106, in train_kmrf_batch
#     data = model.load_data()
#   File "/Users/jessegoodman/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/kmrf.py", line 203, in load_data
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Asset 'iShares Russell 1000 Growth ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#
# ================================================================================
# [19/19] Processing: iShares Russell 1000 Value ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: iShares Russell 1000 Value ETF
#   Asset class: us_equity
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_equity.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_equity/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_equity.csv
#
# ✗ FAILED: iShares Russell 1000 Value ETF
#   Error: Asset 'iShares Russell 1000 Value ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#   Full traceback:
# Traceback (most recent call last):
#   File "/var/folders/gw/n9n80qx50dqb3p299fjcnkzc0000gn/T/ipykernel_42532/2053907266.py", line 106, in train_kmrf_batch
#     data = model.load_data()
#   File "/Users/jessegoodman/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/kmrf.py", line 203, in load_data
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Asset 'iShares Russell 1000 Value ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#
# ================================================================================
# BATCH TRAINING COMPLETE
# ================================================================================
# Total Assets: 19
# Successful: 14
# Failed: 5
#
# ✓ Successfully trained models:
#   - SPDR S&P 500 ETF (6.6 min)
#   - Invesco QQQ Trust (6.0 min)
#   - iShares Russell 2000 ETF (5.3 min)
#   - Energy Select Sector SPDR (5.9 min)
#   - Financial Select Sector SPDR (6.1 min)
#   - Utilities Select Sector SPDR (2.0 min)
#   - Industrial Select Sector SPDR (4.9 min)
#   - Health Care Select Sector SPDR (5.6 min)
#   - Technology Select Sector SPDR (5.7 min)
#   - Materials Select Sector SPDR (4.9 min)
#   - Consumer Discretionary Select Sector SPDR (5.0 min)
#   - Consumer Staples Select Sector SPDR (1.7 min)
#   - iShares S&P 500 Growth ETF (4.6 min)
#   - iShares S&P 500 Value ETF (3.1 min)
#
# ✗ Failed models:
#   - Vanguard S&P 500 ETF: Asset 'Vanguard S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#   - iShares Core S&P 500 ETF: Asset 'iShares Core S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#   - Vanguard Total Stock Market ETF: Asset 'Vanguard Total Stock Market ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#   - iShares Russell 1000 Growth ETF: Asset 'iShares Russell 1000 Growth ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#   - iShares Russell 1000 Value ETF: Asset 'iShares Russell 1000 Value ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
# ✓ Training summary saved to: saved_models/KMRF/original_labels/us_equity/training_summary_20190101.json
# ================================================================================
#
#
# ################################################################################
# # ALL BATCH TRAINING COMPLETE
# ################################################################################
#
# Overall Results:
#   Total Assets Attempted: 19
#   Successful: 14
#   Failed: 5
#   Success Rate: 73.7%
#
# ✗ FAILED: iShares Russell 1000 Value ETF
#   Error: Asset 'iShares Russell 1000 Value ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#   Full traceback:
# Traceback (most recent call last):
#   File "/var/folders/gw/n9n80qx50dqb3p299fjcnkzc0000gn/T/ipykernel_42532/2053907266.py", line 106, in train_kmrf_batch
#     data = model.load_data()
#   File "/Users/jessegoodman/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/kmrf.py", line 203, in load_data
#     raise ValueError(
#     ...<2 lines>...
#     )
# ValueError: Asset 'iShares Russell 1000 Value ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
#
# ================================================================================
# BATCH TRAINING COMPLETE
# ================================================================================
# Total Assets: 19
# Successful: 14
# Failed: 5
#
# ✓ Successfully trained models:
#   - SPDR S&P 500 ETF (6.6 min)
#   - Invesco QQQ Trust (6.0 min)
#   - iShares Russell 2000 ETF (5.3 min)
#   - Energy Select Sector SPDR (5.9 min)
#   - Financial Select Sector SPDR (6.1 min)
#   - Utilities Select Sector SPDR (2.0 min)
#   - Industrial Select Sector SPDR (4.9 min)
#   - Health Care Select Sector SPDR (5.6 min)
#   - Technology Select Sector SPDR (5.7 min)
#   - Materials Select Sector SPDR (4.9 min)
#   - Consumer Discretionary Select Sector SPDR (5.0 min)
#   - Consumer Staples Select Sector SPDR (1.7 min)
#   - iShares S&P 500 Growth ETF (4.6 min)
#   - iShares S&P 500 Value ETF (3.1 min)
#
# ✗ Failed models:
#   - Vanguard S&P 500 ETF: Asset 'Vanguard S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#   - iShares Core S&P 500 ETF: Asset 'iShares Core S&P 500 ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#   - Vanguard Total Stock Market ETF: Asset 'Vanguard Total Stock Market ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#   - iShares Russell 1000 Growth ETF: Asset 'iShares Russell 1000 Growth ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#   - iShares Russell 1000 Value ETF: Asset 'iShares Russell 1000 Value ETF' not found in data. Available assets: SPDR S&P 500 ETF, Invesco S&P 500 Equal Weight ETF, Fidelity Nasdaq Composite Index ETF, Invesco QQQ Trust, iShares Russell 2000 ETF, SPDR Dow Jones Industrial Average ETF, Energy Select Sector SPDR, Financial Select Sector SPDR, Utilities Select Sector SPDR, Industrial Select Sector SPDR...
#
# ✓ Training summary saved to: saved_models/KMRF/original_labels/us_equity/training_summary_20190101.json
# ================================================================================
#
#
# ################################################################################
# # ALL BATCH TRAINING COMPLETE
# ################################################################################
#
# Overall Results:
#   Total Assets Attempted: 19
#   Successful: 14
#   Failed: 5
#   Success Rate: 73.7%
