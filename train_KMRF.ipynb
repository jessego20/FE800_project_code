# %% [markdown]
# # KMRF Model - Batch Training Notebook
#
# This notebook trains KMRF models across multiple assets in batch mode.
#
# **Output Structure:**
# ```
# saved_models/KMRF/
# ├── adapted_labels/
# │   ├── us_equity/
# │   ├── commodity/
# │   └── us_treasury/
# └── original_labels/
#     └── ...
# ```

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from pathlib import Path
from datetime import datetime
from typing import Dict, List, Optional
import traceback
import json

warnings.filterwarnings('ignore')

import kmrf as kmrf

# %matplotlib inline

# %% [markdown]
# ## Asset Lists
#
# Define the assets to train models for:

# %%
# US Equity Assets
us_equity_assets = [
    # Major Indices ETFs
    'SPDR S&P 500 ETF',  # SPY
    'Vanguard S&P 500 ETF',  # VOO
    'iShares Core S&P 500 ETF',  # IVV
    'Invesco QQQ Trust',  # QQQ
    'iShares Russell 2000 ETF',  # IWM
    'Vanguard Total Stock Market ETF',  # VTI
    
    # Sector ETFs (Select Sector SPDRs)
    'Energy Select Sector SPDR',  # XLE
    'Financial Select Sector SPDR',  # XLF
    'Utilities Select Sector SPDR',  # XLU
    'Industrial Select Sector SPDR',  # XLI
    'Health Care Select Sector SPDR',  # XLV
    'Technology Select Sector SPDR',  # XLK
    'Materials Select Sector SPDR',  # XLB
    'Consumer Discretionary Select Sector SPDR',  # XLY
    'Consumer Staples Select Sector SPDR',  # XLP
    
    # Style ETFs
    'iShares S&P 500 Growth ETF',  # IVW
    'iShares S&P 500 Value ETF',  # IVE
    'iShares Russell 1000 Growth ETF',  # IWF
    'iShares Russell 1000 Value ETF',  # IWD
]

# US Treasury Assets
us_treasury_assets = [
    'SPDR Bloomberg 1-3 Month T-Bill ETF',  # BIL
    'iShares 1-3 Year Treasury Bond ETF',  # SHY
    'iShares 7-10 Year Treasury Bond ETF',  # IEF
]

# International Equity ETFs
int_equity_assets = [
    'Vanguard Total International Stock ETF',  # VXUS
    'Vanguard FTSE Developed Markets ETF',  # VEA
    'Vanguard FTSE Emerging Markets ETF',  # VWO
    'Vanguard FTSE Europe ETF',  # VGK
    'Vanguard FTSE Pacific ETF',  # VPL
    'iShares China Large-Cap ETF',  # FXI
    'iShares MSCI Japan ETF',  # EWJ
    'iShares MSCI India ETF',  # INDA
]

# Commodity Assets
commodity_assets = [
    'Gold Futures',
    'Silver Futures',
    'Crude Oil WTI Futures',
    'Natural Gas Futures',
    'Copper Futures',
]

# Map asset classes to their asset lists
ASSET_GROUPS = {
    'us_equity': us_equity_assets,
    'us_treasury': us_treasury_assets,
    'int_equity': int_equity_assets,
    'commodity': commodity_assets,
}

# %% [markdown]
# ## *** Configuration ***
#
# Set batch training parameters:

# %%
# ============================================================================
# BATCH TRAINING CONFIGURATION
# ============================================================================

# Select which asset classes to train
ASSET_CLASSES_TO_TRAIN = ['us_treasury']  # Options: 'us_equity', 'us_treasury', 'int_equity', 'commodity'

# Classification type
CLASSIFICATION_TYPE = 'original'  # 'original' (4 regimes) or 'adapted' (3 regimes)

# Feature selection
USE_BORUTA = True  # WARNING: Boruta is slow
BORUTA_MAX_ITER = 100  # Max iterations for Boruta

# Training/validation/test split dates
END_DATE = '20190101'  # Data up to this date for training
VALIDATION_START = '2019-04-01'
VALIDATION_END = '2019-09-30'
TEST_START = '2020-01-01'

# Other parameters
RANDOM_SEED = 1010
INCLUDE_MACRO = True  # Include macroeconomic features

# Error handling
CONTINUE_ON_ERROR = True  # If True, continue training other assets if one fails
SAVE_SUCCESSFUL_ONLY = True  # Only save models that trained successfully

# Verbose output
VERBOSE = True

# %% [markdown]
# ## Batch Training Function

# %%
def train_kmrf_batch(
    asset_names: List[str],
    asset_class: str,
    classification_type: str = 'adapted',
    end_date: str = '20190101',
    validation_start: str = '2019-04-01',
    validation_end: str = '2019-09-30',
    test_start: str = '2020-01-01',
    use_boruta: bool = False,
    boruta_params: Optional[Dict] = None,
    include_macro: bool = True,
    random_seed: int = 42,
    continue_on_error: bool = True,
    save_successful_only: bool = True,
    verbose: bool = True
) -> Dict[str, Dict]:
    """
    Train KMRF models for multiple assets in batch mode.
    
    Parameters
    ----------
    asset_names : List[str]
        List of asset names to train models for
    asset_class : str
        Asset class ('us_equity', 'us_treasury', 'int_equity', 'commodity')
    classification_type : str, default='adapted'
        Classification type ('original' or 'adapted')
    end_date : str
        Training data end date
    validation_start : str
        Validation period start date
    validation_end : str
        Validation period end date
    test_start : str
        Test period start date
    use_boruta : bool, default=False
        Whether to use Boruta feature selection
    boruta_params : dict, optional
        Parameters for Boruta (default: {'max_iter': 100})
    include_macro : bool, default=True
        Whether to include macroeconomic features
    random_seed : int, default=42
        Random seed for reproducibility
    continue_on_error : bool, default=True
        Whether to continue if one asset fails
    save_successful_only : bool, default=True
        Only save successfully trained models
    verbose : bool, default=True
        Print detailed progress
        
    Returns
    -------
    Dict[str, Dict]
        Dictionary with training results and metadata for each asset
    """
    
    if boruta_params is None:
        boruta_params = {'max_iter': 100}
    
    results = {}
    successful_models = []
    failed_models = []
    
    total_assets = len(asset_names)
    
    print(f"\n{'='*80}")
    print(f"BATCH TRAINING KMRF MODELS")
    print(f"{'='*80}")
    print(f"Asset Class: {asset_class}")
    print(f"Classification Type: {classification_type}")
    print(f"Total Assets: {total_assets}")
    print(f"Use Boruta: {use_boruta}")
    print(f"Include Macro: {include_macro}")
    print(f"Training Period: up to {end_date}")
    print(f"Validation: {validation_start} to {validation_end}")
    print(f"Test: {test_start} onwards")
    print(f"{'='*80}\n")
    
    for idx, asset_name in enumerate(asset_names, 1):
        print(f"\n{'='*80}")
        print(f"[{idx}/{total_assets}] Processing: {asset_name}")
        print(f"{'='*80}")
        
        start_time = datetime.now()
        
        try:
            # Initialize model
            if verbose:
                print(f"\n1. Initializing KMRF model...")
            
            model = kmrf.KMRF(
                asset_name=asset_name,
                asset_class=asset_class,
                end_date=end_date,
                use_ready_data=True,
                validation_start=validation_start,
                validation_end=validation_end,
                test_start=test_start,
                random_seed=random_seed,
                classification_type=classification_type
            )
            
            # Load data
            if verbose:
                print(f"2. Loading data...")
            data = model.load_data()
            features = model.get_features()
            
            if verbose:
                print(f"   Data shape: {data.shape}")
                print(f"   Features shape: {features.shape}")
            
            # Load labels
            if verbose:
                print(f"3. Loading KAMA+MSR labels...")
            model.load_kama_msr_labels()
            
            if classification_type == 'adapted':
                if verbose:
                    print(f"   Adapting to 3-class labels...")
                model.adapt_regime_labels()
            
            # Prepare training data
            if verbose:
                print(f"4. Preparing training data...")
                if use_boruta:
                    print(f"   Running Boruta feature selection (this may take 30+ minutes)...")
            
            X_train, y_train = model.prepare_training_data(
                include_macro=include_macro,
                select_features=use_boruta,
                boruta_params=boruta_params,
                split_data=True
            )
            
            if verbose:
                print(f"   Training samples: {len(X_train)}")
                print(f"   Features: {X_train.shape[1]}")
                if model.selected_features:
                    print(f"   Selected features: {len(model.selected_features)}")
            
            # Train model
            if verbose:
                print(f"5. Training Random Forest model...")
            
            model.fit(X_train, y_train)
            
            # Save model
            if verbose:
                print(f"6. Saving model...")
            
            model_path = model.save_model(boruta_used=use_boruta)
            
            # Record success
            end_time = datetime.now()
            duration = (end_time - start_time).total_seconds()
            
            results[asset_name] = {
                'status': 'success',
                'model_path': str(model_path),
                'n_features': X_train.shape[1],
                'n_selected_features': len(model.selected_features) if model.selected_features else None,
                'n_train_samples': len(X_train),
                'n_test_samples': len(model.X_test) if model.X_test is not None else None,
                'boruta_used': use_boruta,
                'duration_seconds': duration,
                'timestamp': datetime.now().isoformat()
            }
            
            successful_models.append(asset_name)
            
            print(f"\n✓ SUCCESS: {asset_name}")
            print(f"  Model saved to: {model_path}")
            print(f"  Training time: {duration/60:.1f} minutes")
            
        except Exception as e:
            # Record failure
            end_time = datetime.now()
            duration = (end_time - start_time).total_seconds()
            
            error_msg = str(e)
            error_trace = traceback.format_exc()
            
            results[asset_name] = {
                'status': 'failed',
                'error': error_msg,
                'error_trace': error_trace,
                'duration_seconds': duration,
                'timestamp': datetime.now().isoformat()
            }
            
            failed_models.append(asset_name)
            
            print(f"\n✗ FAILED: {asset_name}")
            print(f"  Error: {error_msg}")
            
            if verbose:
                print(f"\n  Full traceback:")
                print(error_trace)
            
            if not continue_on_error:
                print(f"\nStopping batch training due to error.")
                break
    
    # Print summary
    print(f"\n{'='*80}")
    print(f"BATCH TRAINING COMPLETE")
    print(f"{'='*80}")
    print(f"Total Assets: {total_assets}")
    print(f"Successful: {len(successful_models)}")
    print(f"Failed: {len(failed_models)}")
    
    if successful_models:
        print(f"\n✓ Successfully trained models:")
        for name in successful_models:
            duration = results[name]['duration_seconds']
            print(f"  - {name} ({duration/60:.1f} min)")
    
    if failed_models:
        print(f"\n✗ Failed models:")
        for name in failed_models:
            print(f"  - {name}: {results[name]['error']}")
    
    # Save training summary
    summary_dir = Path(f'saved_models/KMRF/{classification_type}_labels/{asset_class}')
    summary_dir.mkdir(parents=True, exist_ok=True)
    summary_path = summary_dir / f'training_summary_{end_date}.json'
    
    with open(summary_path, 'w') as f:
        json.dump(results, f, indent=2)
    
    print(f"\n✓ Training summary saved to: {summary_path}")
    print(f"{'='*80}\n")
    
    return results

# %% [markdown]
# ## Run Batch Training
#
# Execute this cell to train models for all configured asset classes:

# %%
# Run batch training for each selected asset class
all_results = {}

for asset_class in ASSET_CLASSES_TO_TRAIN:
    asset_names = ASSET_GROUPS.get(asset_class, [])
    
    if not asset_names:
        print(f"Warning: No assets defined for class '{asset_class}'. Skipping.")
        continue
    
    print(f"\n{'#'*80}")
    print(f"# TRAINING ASSET CLASS: {asset_class.upper()}")
    print(f"# Assets: {len(asset_names)}")
    print(f"{'#'*80}")
    
    results = train_kmrf_batch(
        asset_names=asset_names,
        asset_class=asset_class,
        classification_type=CLASSIFICATION_TYPE,
        end_date=END_DATE,
        validation_start=VALIDATION_START,
        validation_end=VALIDATION_END,
        test_start=TEST_START,
        use_boruta=USE_BORUTA,
        boruta_params={'max_iter': BORUTA_MAX_ITER},
        include_macro=INCLUDE_MACRO,
        random_seed=RANDOM_SEED,
        continue_on_error=CONTINUE_ON_ERROR,
        save_successful_only=SAVE_SUCCESSFUL_ONLY,
        verbose=VERBOSE
    )
    
    all_results[asset_class] = results

print(f"\n{'#'*80}")
print(f"# ALL BATCH TRAINING COMPLETE")
print(f"{'#'*80}")

# Overall summary
total_attempted = sum(len(results) for results in all_results.values())
total_successful = sum(
    sum(1 for r in results.values() if r['status'] == 'success')
    for results in all_results.values()
)
total_failed = total_attempted - total_successful

print(f"\nOverall Results:")
print(f"  Total Assets Attempted: {total_attempted}")
print(f"  Successful: {total_successful}")
print(f"  Failed: {total_failed}")
print(f"  Success Rate: {100*total_successful/total_attempted:.1f}%")
# Out:
# ################################################################################
# # TRAINING ASSET CLASS: US_TREASURY
# # Assets: 3
# ################################################################################
#
# ================================================================================
# BATCH TRAINING KMRF MODELS
# ================================================================================
# Asset Class: us_treasury
# Classification Type: original
# Total Assets: 3
# Use Boruta: True
# Include Macro: True
# Training Period: up to 20190101
# Validation: 2019-04-01 to 2019-09-30
# Test: 2020-01-01 onwards
# ================================================================================
#
#
# ================================================================================
# [1/3] Processing: SPDR Bloomberg 1-3 Month T-Bill ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: SPDR Bloomberg 1-3 Month T-Bill ETF
#   Asset class: us_treasury
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_treasury.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_treasury/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_treasury.csv
# Loaded data for: SPDR Bloomberg 1-3 Month T-Bill ETF
#   Rows: 9022
#   Columns: 95
#   Date range: 1990-01-02 00:00:00 to 2025-10-24 00:00:00
#
# Extracting pre-computed features for SPDR Bloomberg 1-3 Month T-Bill ETF...
#   Features shape: (9022, 95)
#    Data shape: (9022, 95)
#    Features shape: (9022, 95)
# 3. Loading KAMA+MSR labels...
#
# ================================================================================
# LOADING KAMA+MSR LABELS FOR SPDR Bloomberg 1-3 Month T-Bill ETF
# ================================================================================
# Model directory: saved_models/KAMA_MSR/us_treasury/20190101
# Loading from: SPDR Bloomberg 1-3 Month T-Bill ETF_KAMA-MSR_4-regimes.pkl
# Loaded data for: SPDR Bloomberg 1-3 Month T-Bill ETF
#   Rows: 9022
#   Columns: 95
#   Date range: 1990-01-02 00:00:00 to 2025-10-24 00:00:00
#
# Extracting pre-computed features for SPDR Bloomberg 1-3 Month T-Bill ETF...
#   Features shape: (9022, 95)
#    Data shape: (9022, 95)
#    Features shape: (9022, 95)
# 3. Loading KAMA+MSR labels...
#
# ================================================================================
# LOADING KAMA+MSR LABELS FOR SPDR Bloomberg 1-3 Month T-Bill ETF
# ================================================================================
# Model directory: saved_models/KAMA_MSR/us_treasury/20190101
# Loading from: SPDR Bloomberg 1-3 Month T-Bill ETF_KAMA-MSR_4-regimes.pkl
# ✓ Loaded labels for: SPDR Bloomberg 1-3 Month T-Bill ETF
#   Label date range: 2007-05-31 00:00:00 to 2018-12-31 00:00:00
#   Total periods: 2918
#
#   Original 4-regime distribution:
#     0 -   LV Bullish:     0 (  0.0%)
#     1 -   LV Bearish:     0 (  0.0%)
#     2 -   HV Bullish:   150 (  5.2%)
#     3 -   HV Bearish:  2758 ( 94.8%)
# ================================================================================
# 4. Preparing training data...
#    Running Boruta feature selection (this may take 30+ minutes)...
#
# ================================================================================
# PREPARING TRAINING DATA FOR SPDR Bloomberg 1-3 Month T-Bill ETF
# ================================================================================
#
# Step 1: Technical Features
#   Features Shape: (9022, 95)
#
# Step 2: Loading Macroeconomic Data
#
# Loading macroeconomic data from: data/ready/macro_data_all.csv
# Aligned macro data to features index
# Macro data shape: (9022, 19)
# Macro indicators: 19
#   Combined shape: (9022, 114)
#
# Step 3: Using Original 4-Regime Labels
#   (LV Bullish=0, LV Bearish=1, HV Bullish=2, HV Bearish=3)
#   Labels Shape: (2918,)
#
# Step 4: Cleaning Features - start when labels exist
#   Features date range: 2007-05-31 00:00:00 to 2025-10-24 00:00:00
#   Labels date range: 2007-05-31 00:00:00 to 2018-12-31 00:00:00
#   Dropping 1 features with >50% NaN values
#   Features ready across full date range
#
# Step 5: Splitting Data
#   Train/Validation/Test Split:
#     Training   : Before 2019-04-01
#     Validation : 2019-04-01 to 2019-09-30
#     Test       : 2020-01-01 to End
#
#   Split sizes:
#     Training   : 2918 samples with labels (2007-05-31 to 2018-12-31)
#     Validation : 127 samples (features only, no labels) (2019-04-01 to 2019-09-30)
#     Test       : 1463 samples (features only, no labels) (2020-01-02 to 2025-10-24)
#
#   Applying Boruta feature selection on training data...
#
# ================================================================================
# BORUTA FEATURE SELECTION
# ================================================================================
# Initial features: 113
# Samples: 2918
# Max iterations: 100
#
# Handling missing values...
#   Removed 10 samples with missing values
#   Clean dataset: 2908 samples, 113 features
# Fitting Boruta...
# ✓ Loaded labels for: SPDR Bloomberg 1-3 Month T-Bill ETF
#   Label date range: 2007-05-31 00:00:00 to 2018-12-31 00:00:00
#   Total periods: 2918
#
#   Original 4-regime distribution:
#     0 -   LV Bullish:     0 (  0.0%)
#     1 -   LV Bearish:     0 (  0.0%)
#     2 -   HV Bullish:   150 (  5.2%)
#     3 -   HV Bearish:  2758 ( 94.8%)
# ================================================================================
# 4. Preparing training data...
#    Running Boruta feature selection (this may take 30+ minutes)...
#
# ================================================================================
# PREPARING TRAINING DATA FOR SPDR Bloomberg 1-3 Month T-Bill ETF
# ================================================================================
#
# Step 1: Technical Features
#   Features Shape: (9022, 95)
#
# Step 2: Loading Macroeconomic Data
#
# Loading macroeconomic data from: data/ready/macro_data_all.csv
# Aligned macro data to features index
# Macro data shape: (9022, 19)
# Macro indicators: 19
#   Combined shape: (9022, 114)
#
# Step 3: Using Original 4-Regime Labels
#   (LV Bullish=0, LV Bearish=1, HV Bullish=2, HV Bearish=3)
#   Labels Shape: (2918,)
#
# Step 4: Cleaning Features - start when labels exist
#   Features date range: 2007-05-31 00:00:00 to 2025-10-24 00:00:00
#   Labels date range: 2007-05-31 00:00:00 to 2018-12-31 00:00:00
#   Dropping 1 features with >50% NaN values
#   Features ready across full date range
#
# Step 5: Splitting Data
#   Train/Validation/Test Split:
#     Training   : Before 2019-04-01
#     Validation : 2019-04-01 to 2019-09-30
#     Test       : 2020-01-01 to End
#
#   Split sizes:
#     Training   : 2918 samples with labels (2007-05-31 to 2018-12-31)
#     Validation : 127 samples (features only, no labels) (2019-04-01 to 2019-09-30)
#     Test       : 1463 samples (features only, no labels) (2020-01-02 to 2025-10-24)
#
#   Applying Boruta feature selection on training data...
#
# ================================================================================
# BORUTA FEATURE SELECTION
# ================================================================================
# Initial features: 113
# Samples: 2918
# Max iterations: 100
#
# Handling missing values...
#   Removed 10 samples with missing values
#   Clean dataset: 2908 samples, 113 features
# Fitting Boruta...
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	55
# Tentative: 	58
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	55
# Tentative: 	58
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	55
# Tentative: 	49
# Rejected: 	9
# Iteration: 	11 / 100
# Confirmed: 	55
# Tentative: 	49
# Rejected: 	9
# Iteration: 	12 / 100
# Confirmed: 	55
# Tentative: 	49
# Rejected: 	9
# Iteration: 	12 / 100
# Confirmed: 	55
# Tentative: 	49
# Rejected: 	9
# Iteration: 	13 / 100
# Confirmed: 	55
# Tentative: 	49
# Rejected: 	9
# Iteration: 	13 / 100
# Confirmed: 	55
# Tentative: 	49
# Rejected: 	9
# Iteration: 	14 / 100
# Confirmed: 	55
# Tentative: 	49
# Rejected: 	9
# Iteration: 	14 / 100
# Confirmed: 	55
# Tentative: 	49
# Rejected: 	9
# Iteration: 	15 / 100
# Confirmed: 	61
# Tentative: 	43
# Rejected: 	9
# Iteration: 	15 / 100
# Confirmed: 	61
# Tentative: 	43
# Rejected: 	9
# Iteration: 	16 / 100
# Confirmed: 	61
# Tentative: 	43
# Rejected: 	9
# Iteration: 	16 / 100
# Confirmed: 	61
# Tentative: 	43
# Rejected: 	9
# Iteration: 	17 / 100
# Confirmed: 	61
# Tentative: 	41
# Rejected: 	11
# Iteration: 	17 / 100
# Confirmed: 	61
# Tentative: 	41
# Rejected: 	11
# Iteration: 	18 / 100
# Confirmed: 	61
# Tentative: 	41
# Rejected: 	11
# Iteration: 	18 / 100
# Confirmed: 	61
# Tentative: 	41
# Rejected: 	11
# Iteration: 	19 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	19 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	20 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	20 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	21 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	21 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	22 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	22 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	23 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	23 / 100
# Confirmed: 	62
# Tentative: 	36
# Rejected: 	15
# Iteration: 	24 / 100
# Confirmed: 	62
# Tentative: 	34
# Rejected: 	17
# Iteration: 	24 / 100
# Confirmed: 	62
# Tentative: 	34
# Rejected: 	17
# Iteration: 	25 / 100
# Confirmed: 	62
# Tentative: 	34
# Rejected: 	17
# Iteration: 	25 / 100
# Confirmed: 	62
# Tentative: 	34
# Rejected: 	17
# Iteration: 	26 / 100
# Confirmed: 	62
# Tentative: 	34
# Rejected: 	17
# Iteration: 	26 / 100
# Confirmed: 	62
# Tentative: 	34
# Rejected: 	17
# Iteration: 	27 / 100
# Confirmed: 	62
# Tentative: 	34
# Rejected: 	17
# Iteration: 	27 / 100
# Confirmed: 	62
# Tentative: 	34
# Rejected: 	17
# Iteration: 	28 / 100
# Confirmed: 	62
# Tentative: 	33
# Rejected: 	18
# Iteration: 	28 / 100
# Confirmed: 	62
# Tentative: 	33
# Rejected: 	18
# Iteration: 	29 / 100
# Confirmed: 	65
# Tentative: 	30
# Rejected: 	18
# Iteration: 	29 / 100
# Confirmed: 	65
# Tentative: 	30
# Rejected: 	18
# Iteration: 	30 / 100
# Confirmed: 	65
# Tentative: 	30
# Rejected: 	18
# Iteration: 	30 / 100
# Confirmed: 	65
# Tentative: 	30
# Rejected: 	18
# Iteration: 	31 / 100
# Confirmed: 	65
# Tentative: 	30
# Rejected: 	18
# Iteration: 	31 / 100
# Confirmed: 	65
# Tentative: 	30
# Rejected: 	18
# Iteration: 	32 / 100
# Confirmed: 	65
# Tentative: 	27
# Rejected: 	21
# Iteration: 	32 / 100
# Confirmed: 	65
# Tentative: 	27
# Rejected: 	21
# Iteration: 	33 / 100
# Confirmed: 	65
# Tentative: 	27
# Rejected: 	21
# Iteration: 	33 / 100
# Confirmed: 	65
# Tentative: 	27
# Rejected: 	21
# Iteration: 	34 / 100
# Confirmed: 	65
# Tentative: 	27
# Rejected: 	21
# Iteration: 	34 / 100
# Confirmed: 	65
# Tentative: 	27
# Rejected: 	21
# Iteration: 	35 / 100
# Confirmed: 	66
# Tentative: 	26
# Rejected: 	21
# Iteration: 	35 / 100
# Confirmed: 	66
# Tentative: 	26
# Rejected: 	21
# Iteration: 	36 / 100
# Confirmed: 	66
# Tentative: 	26
# Rejected: 	21
# Iteration: 	36 / 100
# Confirmed: 	66
# Tentative: 	26
# Rejected: 	21
# Iteration: 	37 / 100
# Confirmed: 	66
# Tentative: 	26
# Rejected: 	21
# Iteration: 	37 / 100
# Confirmed: 	66
# Tentative: 	26
# Rejected: 	21
# Iteration: 	38 / 100
# Confirmed: 	66
# Tentative: 	26
# Rejected: 	21
# Iteration: 	38 / 100
# Confirmed: 	66
# Tentative: 	26
# Rejected: 	21
# Iteration: 	39 / 100
# Confirmed: 	66
# Tentative: 	24
# Rejected: 	23
# Iteration: 	39 / 100
# Confirmed: 	66
# Tentative: 	24
# Rejected: 	23
# Iteration: 	40 / 100
# Confirmed: 	66
# Tentative: 	24
# Rejected: 	23
# Iteration: 	40 / 100
# Confirmed: 	66
# Tentative: 	24
# Rejected: 	23
# Iteration: 	41 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	41 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	42 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	42 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	43 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	43 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	44 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	44 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	45 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	45 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	46 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	46 / 100
# Confirmed: 	66
# Tentative: 	22
# Rejected: 	25
# Iteration: 	47 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	47 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	48 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	48 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	49 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	49 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	50 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	50 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	51 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	51 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	52 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	52 / 100
# Confirmed: 	67
# Tentative: 	21
# Rejected: 	25
# Iteration: 	53 / 100
# Confirmed: 	68
# Tentative: 	20
# Rejected: 	25
# Iteration: 	53 / 100
# Confirmed: 	68
# Tentative: 	20
# Rejected: 	25
# Iteration: 	54 / 100
# Confirmed: 	68
# Tentative: 	20
# Rejected: 	25
# Iteration: 	54 / 100
# Confirmed: 	68
# Tentative: 	20
# Rejected: 	25
# Iteration: 	55 / 100
# Confirmed: 	69
# Tentative: 	19
# Rejected: 	25
# Iteration: 	55 / 100
# Confirmed: 	69
# Tentative: 	19
# Rejected: 	25
# Iteration: 	56 / 100
# Confirmed: 	69
# Tentative: 	19
# Rejected: 	25
# Iteration: 	56 / 100
# Confirmed: 	69
# Tentative: 	19
# Rejected: 	25
# Iteration: 	57 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	57 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	58 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	58 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	59 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	59 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	60 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	60 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	61 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	61 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	62 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	62 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	63 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	63 / 100
# Confirmed: 	69
# Tentative: 	18
# Rejected: 	26
# Iteration: 	64 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	64 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	65 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	65 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	66 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	66 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	67 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	67 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	68 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	68 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	69 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	69 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	70 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	70 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	71 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	71 / 100
# Confirmed: 	70
# Tentative: 	17
# Rejected: 	26
# Iteration: 	72 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	72 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	73 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	73 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	74 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	74 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	75 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	75 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	76 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	76 / 100
# Confirmed: 	70
# Tentative: 	16
# Rejected: 	27
# Iteration: 	77 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	77 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	78 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	78 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	79 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	79 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	80 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	80 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	81 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	81 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	82 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	82 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	83 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	83 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	84 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	84 / 100
# Confirmed: 	71
# Tentative: 	15
# Rejected: 	27
# Iteration: 	85 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	85 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	86 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	86 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	87 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	87 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	88 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	88 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	89 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	89 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	90 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	90 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	91 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	91 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	92 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	92 / 100
# Confirmed: 	71
# Tentative: 	14
# Rejected: 	28
# Iteration: 	93 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	93 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	94 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	94 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	95 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	95 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	96 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	96 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	97 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	97 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	98 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	98 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
# Iteration: 	99 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	71
# Tentative: 	8
# Rejected: 	34
#
# ================================================================================
# BORUTA RESULTS
# ================================================================================
# Selected features: 71
# Rejected features: 42
# Tentative features: 8
#
# Top 20 selected features:
#    1. ema_ratio_10d_lag1d                                (importance: 0.109671)
#    2. ema_50_lag1d                                       (importance: 0.058595)
#    3. ema_ratio_20d_lag1d                                (importance: 0.052348)
#    4. high_lag1d                                         (importance: 0.050490)
#    5. vol_252d_lag1d                                     (importance: 0.041432)
#    6. rsi_30d_lag1d                                      (importance: 0.037629)
#    7. macd_histogram_lag1d                               (importance: 0.030536)
#    8. log_ret_60d_lag1d                                  (importance: 0.026180)
#    9. log_ret_20d_lag1d                                  (importance: 0.020714)
#   10. open_lag1d                                         (importance: 0.019907)
#   11. macd_lag1d                                         (importance: 0.019481)
#   12. vol_60d_lag1d                                      (importance: 0.018668)
#   13. tsfresh_close_lag1d__mean                          (importance: 0.017931)
#   14. log_ret_120d_lag1d                                 (importance: 0.016497)
#   15. tsfresh_close_lag1d__sum_values                    (importance: 0.015807)
#   16. parkinson_vol_60d_lag1d                            (importance: 0.015150)
#   17. ema_100_lag1d                                      (importance: 0.013600)
#   18. parkinson_vol_20d_lag1d                            (importance: 0.013185)
#   19. close_lag1d                                        (importance: 0.011642)
#   20. ema_ratio_60d_lag1d                                (importance: 0.010371)
#   Feature selection applied to all splits
#
#   Label distribution:
#     Training (with labels):
#        HV_Bull ( 2):   150 (  5.1%)
#        HV_Bear ( 3):  2758 ( 94.5%)
#     Validation: No labels (prediction only)
#     Test: No labels (prediction only)
#
# ================================================================================
# DATA PREPARATION COMPLETE
# ================================================================================
#
# Note: Validation and test sets have features only.
#       Use trained model to generate predictions on these sets.
# Iteration: 	99 / 100
# Confirmed: 	71
# Tentative: 	13
# Rejected: 	29
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	71
# Tentative: 	8
# Rejected: 	34
#
# ================================================================================
# BORUTA RESULTS
# ================================================================================
# Selected features: 71
# Rejected features: 42
# Tentative features: 8
#
# Top 20 selected features:
#    1. ema_ratio_10d_lag1d                                (importance: 0.109671)
#    2. ema_50_lag1d                                       (importance: 0.058595)
#    3. ema_ratio_20d_lag1d                                (importance: 0.052348)
#    4. high_lag1d                                         (importance: 0.050490)
#    5. vol_252d_lag1d                                     (importance: 0.041432)
#    6. rsi_30d_lag1d                                      (importance: 0.037629)
#    7. macd_histogram_lag1d                               (importance: 0.030536)
#    8. log_ret_60d_lag1d                                  (importance: 0.026180)
#    9. log_ret_20d_lag1d                                  (importance: 0.020714)
#   10. open_lag1d                                         (importance: 0.019907)
#   11. macd_lag1d                                         (importance: 0.019481)
#   12. vol_60d_lag1d                                      (importance: 0.018668)
#   13. tsfresh_close_lag1d__mean                          (importance: 0.017931)
#   14. log_ret_120d_lag1d                                 (importance: 0.016497)
#   15. tsfresh_close_lag1d__sum_values                    (importance: 0.015807)
#   16. parkinson_vol_60d_lag1d                            (importance: 0.015150)
#   17. ema_100_lag1d                                      (importance: 0.013600)
#   18. parkinson_vol_20d_lag1d                            (importance: 0.013185)
#   19. close_lag1d                                        (importance: 0.011642)
#   20. ema_ratio_60d_lag1d                                (importance: 0.010371)
#   Feature selection applied to all splits
#
#   Label distribution:
#     Training (with labels):
#        HV_Bull ( 2):   150 (  5.1%)
#        HV_Bear ( 3):  2758 ( 94.5%)
#     Validation: No labels (prediction only)
#     Test: No labels (prediction only)
#
# ================================================================================
# DATA PREPARATION COMPLETE
# ================================================================================
#
# Note: Validation and test sets have features only.
#       Use trained model to generate predictions on these sets.
#    Training samples: 2918
#    Features: 71
#    Selected features: 71
# 5. Training Random Forest model...
#
# ================================================================================
# TRAINING RANDOM FOREST CLASSIFIER
# ================================================================================
# RF Parameters:
#   n_estimators: 220
#   max_depth: 13
#   min_samples_split: 76
#   min_samples_leaf: 95
#   max_samples: 0.36
#   max_features: 0.25
#   min_weight_fraction_leaf: 0.045
#   random_state: 1010
#   n_jobs: -1
#
# Training samples: 2908
# Features: 71
# Date range: 2007-06-14 00:00:00 to 2018-12-31 00:00:00
#
# Fitting Random Forest...
#    Training samples: 2918
#    Features: 71
#    Selected features: 71
# 5. Training Random Forest model...
#
# ================================================================================
# TRAINING RANDOM FOREST CLASSIFIER
# ================================================================================
# RF Parameters:
#   n_estimators: 220
#   max_depth: 13
#   min_samples_split: 76
#   min_samples_leaf: 95
#   max_samples: 0.36
#   max_features: 0.25
#   min_weight_fraction_leaf: 0.045
#   random_state: 1010
#   n_jobs: -1
#
# Training samples: 2908
# Features: 71
# Date range: 2007-06-14 00:00:00 to 2018-12-31 00:00:00
#
# Fitting Random Forest...
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Model ready for prediction
# 6. Saving model...
#
# Saving model to: saved_models/KMRF/original_labels/us_treasury/KMRF_SPDR-Bloomberg-1-3-Month-T-Bill-ETF_20190101_boruta.pkl
#   Asset: SPDR Bloomberg 1-3 Month T-Bill ETF
#   Classification type: original
#   Features: 71
#   Training samples: 2918
# ✓ Model saved successfully
#
# ✓ SUCCESS: SPDR Bloomberg 1-3 Month T-Bill ETF
#   Model saved to: saved_models/KMRF/original_labels/us_treasury/KMRF_SPDR-Bloomberg-1-3-Month-T-Bill-ETF_20190101_boruta.pkl
#   Training time: 1.0 minutes
#
# ================================================================================
# [2/3] Processing: iShares 1-3 Year Treasury Bond ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: iShares 1-3 Year Treasury Bond ETF
#   Asset class: us_treasury
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_treasury.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_treasury/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_treasury.csv
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Model ready for prediction
# 6. Saving model...
#
# Saving model to: saved_models/KMRF/original_labels/us_treasury/KMRF_SPDR-Bloomberg-1-3-Month-T-Bill-ETF_20190101_boruta.pkl
#   Asset: SPDR Bloomberg 1-3 Month T-Bill ETF
#   Classification type: original
#   Features: 71
#   Training samples: 2918
# ✓ Model saved successfully
#
# ✓ SUCCESS: SPDR Bloomberg 1-3 Month T-Bill ETF
#   Model saved to: saved_models/KMRF/original_labels/us_treasury/KMRF_SPDR-Bloomberg-1-3-Month-T-Bill-ETF_20190101_boruta.pkl
#   Training time: 1.0 minutes
#
# ================================================================================
# [2/3] Processing: iShares 1-3 Year Treasury Bond ETF
# ================================================================================
#
# 1. Initializing KMRF model...
# KMRF model initialized
#   Asset: iShares 1-3 Year Treasury Bond ETF
#   Asset class: us_treasury
#   Classification type: original
#   End date: 20190101
#   Using pre-computed features: True
#   Data path: data/ready/us_treasury.csv
#   KAMA+MSR model directory: saved_models/KAMA_MSR/us_treasury/20190101
#   Validation period: 2019-04-01 to 2019-09-30
#   Test start: 2020-01-01
#   Random seed: 1010
# 2. Loading data...
#
# Loading data from: data/ready/us_treasury.csv
# Loaded data for: iShares 1-3 Year Treasury Bond ETF
#   Rows: 9022
#   Columns: 95
#   Date range: 1990-01-02 00:00:00 to 2025-10-24 00:00:00
#
# Extracting pre-computed features for iShares 1-3 Year Treasury Bond ETF...
#   Features shape: (9022, 95)
#    Data shape: (9022, 95)
#    Features shape: (9022, 95)
# 3. Loading KAMA+MSR labels...
#
# ================================================================================
# LOADING KAMA+MSR LABELS FOR iShares 1-3 Year Treasury Bond ETF
# ================================================================================
# Model directory: saved_models/KAMA_MSR/us_treasury/20190101
# Loading from: iShares 1-3 Year Treasury Bond ETF_KAMA-MSR_4-regimes.pkl
# ✓ Loaded labels for: iShares 1-3 Year Treasury Bond ETF
#   Label date range: 2002-07-29 00:00:00 to 2018-12-31 00:00:00
#   Total periods: 4136
#
#   Original 4-regime distribution:
#     0 -   LV Bullish:  1440 ( 35.0%)
#     1 -   LV Bearish:  2670 ( 65.0%)
#     2 -   HV Bullish:     0 (  0.0%)
#     3 -   HV Bearish:     0 (  0.0%)
# ================================================================================
# 4. Preparing training data...
#    Running Boruta feature selection (this may take 30+ minutes)...
#
# ================================================================================
# PREPARING TRAINING DATA FOR iShares 1-3 Year Treasury Bond ETF
# ================================================================================
#
# Step 1: Technical Features
#   Features Shape: (9022, 95)
#
# Step 2: Loading Macroeconomic Data
#
# Loading macroeconomic data from: data/ready/macro_data_all.csv
# Aligned macro data to features index
# Macro data shape: (9022, 19)
# Macro indicators: 19
#   Combined shape: (9022, 114)
#
# Step 3: Using Original 4-Regime Labels
#   (LV Bullish=0, LV Bearish=1, HV Bullish=2, HV Bearish=3)
#   Labels Shape: (4136,)
#
# Step 4: Cleaning Features - start when labels exist
#   Features date range: 2002-07-29 00:00:00 to 2025-10-24 00:00:00
#   Labels date range: 2002-07-29 00:00:00 to 2018-12-31 00:00:00
#   Dropping 1 features with >50% NaN values
#   Features ready across full date range
#
# Step 5: Splitting Data
#   Train/Validation/Test Split:
#     Training   : Before 2019-04-01
#     Validation : 2019-04-01 to 2019-09-30
#     Test       : 2020-01-01 to End
#
#   Split sizes:
#     Training   : 4136 samples with labels (2002-07-29 to 2018-12-31)
#     Validation : 127 samples (features only, no labels) (2019-04-01 to 2019-09-30)
#     Test       : 1463 samples (features only, no labels) (2020-01-02 to 2025-10-24)
#
#   Applying Boruta feature selection on training data...
#
# ================================================================================
# BORUTA FEATURE SELECTION
# ================================================================================
# Initial features: 113
# Samples: 4136
# Max iterations: 100
#
# Handling missing values...
#   Removed 26 samples with missing values
#   Clean dataset: 4110 samples, 113 features
# Fitting Boruta...
# Loaded data for: iShares 1-3 Year Treasury Bond ETF
#   Rows: 9022
#   Columns: 95
#   Date range: 1990-01-02 00:00:00 to 2025-10-24 00:00:00
#
# Extracting pre-computed features for iShares 1-3 Year Treasury Bond ETF...
#   Features shape: (9022, 95)
#    Data shape: (9022, 95)
#    Features shape: (9022, 95)
# 3. Loading KAMA+MSR labels...
#
# ================================================================================
# LOADING KAMA+MSR LABELS FOR iShares 1-3 Year Treasury Bond ETF
# ================================================================================
# Model directory: saved_models/KAMA_MSR/us_treasury/20190101
# Loading from: iShares 1-3 Year Treasury Bond ETF_KAMA-MSR_4-regimes.pkl
# ✓ Loaded labels for: iShares 1-3 Year Treasury Bond ETF
#   Label date range: 2002-07-29 00:00:00 to 2018-12-31 00:00:00
#   Total periods: 4136
#
#   Original 4-regime distribution:
#     0 -   LV Bullish:  1440 ( 35.0%)
#     1 -   LV Bearish:  2670 ( 65.0%)
#     2 -   HV Bullish:     0 (  0.0%)
#     3 -   HV Bearish:     0 (  0.0%)
# ================================================================================
# 4. Preparing training data...
#    Running Boruta feature selection (this may take 30+ minutes)...
#
# ================================================================================
# PREPARING TRAINING DATA FOR iShares 1-3 Year Treasury Bond ETF
# ================================================================================
#
# Step 1: Technical Features
#   Features Shape: (9022, 95)
#
# Step 2: Loading Macroeconomic Data
#
# Loading macroeconomic data from: data/ready/macro_data_all.csv
# Aligned macro data to features index
# Macro data shape: (9022, 19)
# Macro indicators: 19
#   Combined shape: (9022, 114)
#
# Step 3: Using Original 4-Regime Labels
#   (LV Bullish=0, LV Bearish=1, HV Bullish=2, HV Bearish=3)
#   Labels Shape: (4136,)
#
# Step 4: Cleaning Features - start when labels exist
#   Features date range: 2002-07-29 00:00:00 to 2025-10-24 00:00:00
#   Labels date range: 2002-07-29 00:00:00 to 2018-12-31 00:00:00
#   Dropping 1 features with >50% NaN values
#   Features ready across full date range
#
# Step 5: Splitting Data
#   Train/Validation/Test Split:
#     Training   : Before 2019-04-01
#     Validation : 2019-04-01 to 2019-09-30
#     Test       : 2020-01-01 to End
#
#   Split sizes:
#     Training   : 4136 samples with labels (2002-07-29 to 2018-12-31)
#     Validation : 127 samples (features only, no labels) (2019-04-01 to 2019-09-30)
#     Test       : 1463 samples (features only, no labels) (2020-01-02 to 2025-10-24)
#
#   Applying Boruta feature selection on training data...
#
# ================================================================================
# BORUTA FEATURE SELECTION
# ================================================================================
# Initial features: 113
# Samples: 4136
# Max iterations: 100
#
# Handling missing values...
#   Removed 26 samples with missing values
#   Clean dataset: 4110 samples, 113 features
# Fitting Boruta...
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	103
# Tentative: 	10
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	103
# Tentative: 	10
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	103
# Tentative: 	10
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	103
# Tentative: 	10
# Rejected: 	0
# Iteration: 	12 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	12 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	13 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	13 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	14 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	14 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	15 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	15 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	16 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	16 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	17 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	17 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	18 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	18 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	19 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	19 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	20 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	20 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	21 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	21 / 100
# Confirmed: 	103
# Tentative: 	5
# Rejected: 	5
# Iteration: 	22 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	22 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	23 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	23 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	24 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	24 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	25 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	25 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	26 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	26 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	27 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	27 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	28 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	28 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	29 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	29 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	30 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	30 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	31 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	31 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	32 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	32 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	33 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	33 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	34 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	34 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	35 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	35 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	36 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	36 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	37 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	37 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	38 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	38 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	39 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	39 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	40 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	41 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	40 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	41 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	42 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	42 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	43 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	43 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	44 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	44 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	45 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	45 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	46 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	46 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	47 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	47 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	48 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	48 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	49 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	49 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	50 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	50 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	51 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	51 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	52 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	52 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	53 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	53 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	54 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	54 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	55 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	55 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	56 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	56 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	57 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	57 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	58 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	58 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	59 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	59 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	60 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	60 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	61 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	61 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	62 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	62 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	63 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	63 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	64 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	64 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	65 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	65 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	66 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	66 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	67 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	67 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	68 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	68 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	69 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	69 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	70 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	70 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	71 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	71 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	72 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	72 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	73 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	73 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	74 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	74 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	75 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	75 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	76 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	76 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	77 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	77 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	78 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	78 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	79 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	79 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	80 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	80 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	81 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	81 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	82 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	82 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	83 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	83 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	84 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	84 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	85 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	85 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	86 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	86 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	87 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	87 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	88 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	88 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	89 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	89 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	90 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	90 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	91 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	91 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	92 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	92 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	93 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	93 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	94 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	94 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	95 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	95 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	96 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	96 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	97 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	97 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	98 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	98 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
# Iteration: 	99 / 100
# Confirmed: 	104
# Tentative: 	2
# Rejected: 	7
#
#
# BorutaPy finished running.
#
# Iteration: 	100 / 100
# Confirmed: 	104
# Tentative: 	0
# Rejected: 	9
#
# ================================================================================
# BORUTA RESULTS
# ================================================================================
# Selected features: 104
# Rejected features: 9
# Tentative features: 0
#
# Top 20 selected features:
# ...
#    Running Boruta feature selection (this may take 30+ minutes)...
#
# ================================================================================
# PREPARING TRAINING DATA FOR iShares 7-10 Year Treasury Bond ETF
# ================================================================================
#
# Step 1: Technical Features
#   Features Shape: (9022, 95)
#
# Step 2: Loading Macroeconomic Data
#
# Loading macroeconomic data from: data/ready/macro_data_all.csv
# Aligned macro data to features index
# Macro data shape: (9022, 19)
# Macro indicators: 19
#   Combined shape: (9022, 114)
#
# Step 3: Using Original 4-Regime Labels
#   (LV Bullish=0, LV Bearish=1, HV Bullish=2, HV Bearish=3)
#   Labels Shape: (4136,)
#
# Step 4: Cleaning Features - start when labels exist
#   Features date range: 2002-07-29 00:00:00 to 2025-10-24 00:00:00
#   Labels date range: 2002-07-29 00:00:00 to 2018-12-31 00:00:00
#   Dropping 1 features with >50% NaN values
#   Features ready across full date range
#
# Step 5: Splitting Data
#   Train/Validation/Test Split:
#     Training   : Before 2019-04-01
#     Validation : 2019-04-01 to 2019-09-30
#     Test       : 2020-01-01 to End
#
#   Split sizes:
#     Training   : 4136 samples with labels (2002-07-29 to 2018-12-31)
#     Validation : 127 samples (features only, no labels) (2019-04-01 to 2019-09-30)
#     Test       : 1463 samples (features only, no labels) (2020-01-02 to 2025-10-24)
#
#   Applying Boruta feature selection on training data...
#
# ================================================================================
# BORUTA FEATURE SELECTION
# ================================================================================
# Initial features: 113
# Samples: 4136
# Max iterations: 100
#
# Handling missing values...
#   Removed 26 samples with missing values
#   Clean dataset: 4110 samples, 113 features
# Fitting Boruta...
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	1 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	2 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	3 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	4 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	5 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	6 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	7 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	8 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	9 / 100
# Confirmed: 	0
# Tentative: 	113
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	103
# Tentative: 	10
# Rejected: 	0
# Iteration: 	10 / 100
# Confirmed: 	103
# Tentative: 	10
# Rejected: 	0
# Iteration: 	11 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	11 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	12 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	12 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	13 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	13 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	14 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	14 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	15 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	16 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	17 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	15 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	16 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	17 / 100
# Confirmed: 	103
# Tentative: 	4
# Rejected: 	6
# Iteration: 	18 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	19 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	20 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	21 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	18 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	19 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	20 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	21 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	22 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	23 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	24 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	25 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	26 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	27 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	28 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	29 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	30 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	31 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	32 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	33 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	34 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	35 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	36 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	37 / 100
# Confirmed: 	103
# Tentative: 	0
# Rejected: 	10
#
#
# BorutaPy finished running.
#
# Iteration: 	38 / 100
# Confirmed: 	103
# Tentative: 	0
# Rejected: 	10
#
# ================================================================================
# BORUTA RESULTS
# ================================================================================
# Selected features: 103
# Rejected features: 10
# Tentative features: 0
#
# Top 20 selected features:
#    1. bb_lower_lag1d                                     (importance: 0.129940)
#    2. bb_width_lag1d                                     (importance: 0.119974)
#    3. ema_ratio_120d_lag1d                               (importance: 0.099980)
#    4. momentum_252d_lag1d                                (importance: 0.073209)
#    5. gk_vol_120d_lag1d                                  (importance: 0.053235)
#    6. ema_ratio_10d_lag1d                                (importance: 0.042586)
#    7. gk_vol_252d_lag1d                                  (importance: 0.041725)
#    8. log_ret_5d_lag1d                                   (importance: 0.035970)
#    9. log_ret_lag1d                                      (importance: 0.032707)
#   10. ema_ratio_60d_lag1d                                (importance: 0.024576)
#   11. momentum_120d_lag1d                                (importance: 0.019560)
#   12. bb_upper_lag1d                                     (importance: 0.018543)
#   13. gk_vol_60d_lag1d                                   (importance: 0.014992)
#   14. ema_ratio_20d_lag1d                                (importance: 0.012669)
#   15. bb_position_lag1d                                  (importance: 0.009670)
#   16. momentum_20d_lag1d                                 (importance: 0.009000)
#   17. kurt_60d_lag1d                                     (importance: 0.007885)
#   18. volume_ma_20_lag1d                                 (importance: 0.007455)
#   19. log_ret_20d_lag1d                                  (importance: 0.007338)
#   20. atr_14_lag1d                                       (importance: 0.007002)
#   Feature selection applied to all splits
#
#   Label distribution:
#     Training (with labels):
#        HV_Bull ( 2):  1554 ( 37.6%)
#        HV_Bear ( 3):  2556 ( 61.8%)
#     Validation: No labels (prediction only)
#     Test: No labels (prediction only)
#
# ================================================================================
# DATA PREPARATION COMPLETE
# ================================================================================
#
# Note: Validation and test sets have features only.
#       Use trained model to generate predictions on these sets.
#    Training samples: 4136
#    Features: 103
#    Selected features: 103
# 5. Training Random Forest model...
#
# ================================================================================
# TRAINING RANDOM FOREST CLASSIFIER
# ================================================================================
# RF Parameters:
#   n_estimators: 220
#   max_depth: 13
#   min_samples_split: 76
#   min_samples_leaf: 95
#   max_samples: 0.36
#   max_features: 0.25
#   min_weight_fraction_leaf: 0.045
#   random_state: 1010
#   n_jobs: -1
#
# Training samples: 4110
# Features: 103
# Date range: 2002-09-04 00:00:00 to 2018-12-31 00:00:00
#
# Fitting Random Forest...
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Model ready for prediction
# 6. Saving model...
#
# Saving model to: saved_models/KMRF/original_labels/us_treasury/KMRF_iShares-7-10-Year-Treasury-Bond-ETF_20190101_boruta.pkl
#   Asset: iShares 7-10 Year Treasury Bond ETF
#   Classification type: original
#   Features: 103
#   Training samples: 4136
# ✓ Model saved successfully
#
# ✓ SUCCESS: iShares 7-10 Year Treasury Bond ETF
#   Model saved to: saved_models/KMRF/original_labels/us_treasury/KMRF_iShares-7-10-Year-Treasury-Bond-ETF_20190101_boruta.pkl
#   Training time: 1.1 minutes
#
# ================================================================================
# BATCH TRAINING COMPLETE
# ================================================================================
# Total Assets: 3
# Successful: 3
# Failed: 0
#
# ✓ Successfully trained models:
#   - SPDR Bloomberg 1-3 Month T-Bill ETF (1.0 min)
#   - iShares 1-3 Year Treasury Bond ETF (3.0 min)
#   - iShares 7-10 Year Treasury Bond ETF (1.1 min)
#
# ✓ Training summary saved to: saved_models/KMRF/original_labels/us_treasury/training_summary_20190101.json
# ================================================================================
#
#
# ################################################################################
# # ALL BATCH TRAINING COMPLETE
# ################################################################################
#
# Overall Results:
#   Total Assets Attempted: 3
#   Successful: 3
#   Failed: 0
#   Success Rate: 100.0%
# Iteration: 	22 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	23 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	24 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	25 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	26 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	27 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	28 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	29 / 100
# Confirmed: 	103
# Tentative: 	3
# Rejected: 	7
# Iteration: 	30 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	31 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	32 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	33 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	34 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	35 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	36 / 100
# Confirmed: 	103
# Tentative: 	1
# Rejected: 	9
# Iteration: 	37 / 100
# Confirmed: 	103
# Tentative: 	0
# Rejected: 	10
#
#
# BorutaPy finished running.
#
# Iteration: 	38 / 100
# Confirmed: 	103
# Tentative: 	0
# Rejected: 	10
#
# ================================================================================
# BORUTA RESULTS
# ================================================================================
# Selected features: 103
# Rejected features: 10
# Tentative features: 0
#
# Top 20 selected features:
#    1. bb_lower_lag1d                                     (importance: 0.129940)
#    2. bb_width_lag1d                                     (importance: 0.119974)
#    3. ema_ratio_120d_lag1d                               (importance: 0.099980)
#    4. momentum_252d_lag1d                                (importance: 0.073209)
#    5. gk_vol_120d_lag1d                                  (importance: 0.053235)
#    6. ema_ratio_10d_lag1d                                (importance: 0.042586)
#    7. gk_vol_252d_lag1d                                  (importance: 0.041725)
#    8. log_ret_5d_lag1d                                   (importance: 0.035970)
#    9. log_ret_lag1d                                      (importance: 0.032707)
#   10. ema_ratio_60d_lag1d                                (importance: 0.024576)
#   11. momentum_120d_lag1d                                (importance: 0.019560)
#   12. bb_upper_lag1d                                     (importance: 0.018543)
#   13. gk_vol_60d_lag1d                                   (importance: 0.014992)
#   14. ema_ratio_20d_lag1d                                (importance: 0.012669)
#   15. bb_position_lag1d                                  (importance: 0.009670)
#   16. momentum_20d_lag1d                                 (importance: 0.009000)
#   17. kurt_60d_lag1d                                     (importance: 0.007885)
#   18. volume_ma_20_lag1d                                 (importance: 0.007455)
#   19. log_ret_20d_lag1d                                  (importance: 0.007338)
#   20. atr_14_lag1d                                       (importance: 0.007002)
#   Feature selection applied to all splits
#
#   Label distribution:
#     Training (with labels):
#        HV_Bull ( 2):  1554 ( 37.6%)
#        HV_Bear ( 3):  2556 ( 61.8%)
#     Validation: No labels (prediction only)
#     Test: No labels (prediction only)
#
# ================================================================================
# DATA PREPARATION COMPLETE
# ================================================================================
#
# Note: Validation and test sets have features only.
#       Use trained model to generate predictions on these sets.
#    Training samples: 4136
#    Features: 103
#    Selected features: 103
# 5. Training Random Forest model...
#
# ================================================================================
# TRAINING RANDOM FOREST CLASSIFIER
# ================================================================================
# RF Parameters:
#   n_estimators: 220
#   max_depth: 13
#   min_samples_split: 76
#   min_samples_leaf: 95
#   max_samples: 0.36
#   max_features: 0.25
#   min_weight_fraction_leaf: 0.045
#   random_state: 1010
#   n_jobs: -1
#
# Training samples: 4110
# Features: 103
# Date range: 2002-09-04 00:00:00 to 2018-12-31 00:00:00
#
# Fitting Random Forest...
#
# ================================================================================
# TRAINING COMPLETE
# ================================================================================
# Model ready for prediction
# 6. Saving model...
#
# Saving model to: saved_models/KMRF/original_labels/us_treasury/KMRF_iShares-7-10-Year-Treasury-Bond-ETF_20190101_boruta.pkl
#   Asset: iShares 7-10 Year Treasury Bond ETF
#   Classification type: original
#   Features: 103
#   Training samples: 4136
# ✓ Model saved successfully
#
# ✓ SUCCESS: iShares 7-10 Year Treasury Bond ETF
#   Model saved to: saved_models/KMRF/original_labels/us_treasury/KMRF_iShares-7-10-Year-Treasury-Bond-ETF_20190101_boruta.pkl
#   Training time: 1.1 minutes
#
# ================================================================================
# BATCH TRAINING COMPLETE
# ================================================================================
# Total Assets: 3
# Successful: 3
# Failed: 0
#
# ✓ Successfully trained models:
#   - SPDR Bloomberg 1-3 Month T-Bill ETF (1.0 min)
#   - iShares 1-3 Year Treasury Bond ETF (3.0 min)
#   - iShares 7-10 Year Treasury Bond ETF (1.1 min)
#
# ✓ Training summary saved to: saved_models/KMRF/original_labels/us_treasury/training_summary_20190101.json
# ================================================================================
#
#
# ################################################################################
# # ALL BATCH TRAINING COMPLETE
# ################################################################################
#
# Overall Results:
#   Total Assets Attempted: 3
#   Successful: 3
#   Failed: 0
#   Success Rate: 100.0%
