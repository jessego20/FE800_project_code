# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
from pathlib import Path
import pickle
import warnings
import os
from typing import Dict, List, Tuple, Optional

warnings.filterwarnings('ignore')

from kmrf import KMRF
from KMRF_training_config import *
from SIMULATOR import SIMULATOR
from OPTIMIZER_INPUTS import OPTIMIZER_INPUTS
from BACKTEST import BACKTEST, generate_rebalance_dates


# Set visualization style
plt.style.use('seaborn-v0_8-darkgrid')
sns.set_palette("husl")

print("✓ Libraries imported successfully")
print(f"  Pandas version: {pd.__version__}")
print(f"  NumPy version: {np.__version__}")
# Out:
# ✓ Libraries imported successfully
#   Pandas version: 2.3.3
#   NumPy version: 2.3.4

# %% [markdown]
# ## Multi-Horizon Regime Predictions

# %% [markdown]
# #### Global Vars and Helper Functions

# %%
KM_MODEL_BASE_PATH = Path('saved_models/KAMA_MSR/us_equity')
KMRF_PREDICTIONS_BASE_PATH = Path('data/multi_horizon_predictions')

# Using saved KAMA+MSR models
def get_KM_model_dates(KM_MODEL_BASE_PATH = Path('saved_models/KAMA_MSR/us_equity')) -> pd.Series:
    return pd.Series([f.stem for f in list(KM_MODEL_BASE_PATH.glob('*'))]).sort_values().iloc[1:].reset_index(drop=True)

def get_KM_model_paths(MODEL_DATE: str, KM_MODEL_BASE_PATH = Path('saved_models/KAMA_MSR/us_equity')) ->  pd.Series:
    return pd.Series(list((KM_MODEL_BASE_PATH / MODEL_DATE).glob('*'))).sort_values().reset_index(drop=True)

# Using saved KMRF predictions
def get_asset_names(KMRF_PREDICTIONS_BASE_PATH = Path('data/multi_horizon_predictions')) -> pd.Series:
    kmrf_preds_paths = list(KMRF_PREDICTIONS_BASE_PATH.glob('*'))
    return pd.Series([f.stem.split('multi')[0][:-1].replace('_', ' ') for f in kmrf_preds_paths]).sort_values().reset_index(drop=True)

def get_KMRF_prediction_paths(KMRF_PREDICTIONS_BASE_PATH = Path('data/multi_horizon_predictions')) -> pd.Series:
    return pd.Series(list(KMRF_PREDICTIONS_BASE_PATH.glob('*'))).sort_values().reset_index(drop=True)

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay

TRADING_DAYS = CustomBusinessDay(calendar=USFederalHolidayCalendar())

# %% [markdown]
# #### --------------------------------------------------------

# %%
RISK_FREE_RATES = pd.read_csv('data/risk_free_rates.csv', parse_dates=['Date'], index_col='Date')
RISK_FREE_RATES = RISK_FREE_RATES['RF_3M'].rename('RF').to_frame()

# %%
KM_MODEL_DATES = get_KM_model_dates()
ASSET_NAMES = get_asset_names()

display(ASSET_NAMES)
# Out:
# 0     Consumer Discretionary Select Sector SPDR
# 1           Consumer Staples Select Sector SPDR
# 2                     Energy Select Sector SPDR
# 3                  Financial Select Sector SPDR
# 4                Health Care Select Sector SPDR
# 5                 Industrial Select Sector SPDR
# 6                        Invesco DB Agriculture
# 7                             Invesco QQQ Trust
# 8                  Materials Select Sector SPDR
# 9         SPDR Dow Jones Industrial Average ETF
# 10                             SPDR Gold Shares
# 11                             SPDR S&P 500 ETF
# 12                Technology Select Sector SPDR
# 13               United States Natural Gas Fund
# 14                       United States Oil Fund
# 15                 Utilities Select Sector SPDR
# 16          Vanguard FTSE Developed Markets ETF
# 17           Vanguard FTSE Emerging Markets ETF
# 18                     Vanguard FTSE Europe ETF
# 19                  iShares China Large-Cap ETF
# 20                       iShares MSCI India ETF
# 21                       iShares MSCI Japan ETF
# 22                        iShares Micro-Cap ETF
# 23                     iShares Russell 2000 ETF
# 24              iShares Russell 2000 Growth ETF
# 25               iShares Russell 2000 Value ETF
# 26                  iShares Russell Mid-Cap ETF
# 27                   iShares S&P 500 Growth ETF
# 28                    iShares S&P 500 Value ETF
# 29                         iShares Silver Trust
# 30                 iShares U.S. Real Estate ETF
# dtype: object

# %%
KM_MODEL_DATES.iloc[-12]
# Out:
# '20241101'

# %%
PORTFOLIO_ASSETS = ['Technology Select Sector SPDR', 'Health Care Select Sector SPDR', 'Financial Select Sector SPDR',
                    'Consumer Discretionary Select Sector SPDR', 'Consumer Staples Select Sector SPDR', 
                    'Industrial Select Sector SPDR', 'Energy Select Sector SPDR', 'Utilities Select Sector SPDR',
                    'Materials Select Sector SPDR', 'iShares U.S. Real Estate ETF']
# Add a day first because optimization dates are the first day of the prediction period
# even though we want to optimize at the end of the previous trading day
# e.g., optimize on 2018-12-31 for the 21 trading day period starting 2019-01-02
# Risk-free rate is taken from the previous trading day
OPT_DATE = pd.Timestamp(KM_MODEL_DATES.iloc[-12]) + TRADING_DAYS
RISK_FREE = RISK_FREE_RATES.loc[OPT_DATE - TRADING_DAYS].values[0]
OPT_INPUTS = OPTIMIZER_INPUTS(opt_date=OPT_DATE, asset_list=PORTFOLIO_ASSETS, risk_free_rate=RISK_FREE, 
                              n_days=21, n_simulations=250, random_seed=42)
print("Optimization Date:", OPT_INPUTS.opt_date.date())
print(f"Risk-Free Rate ({(OPT_DATE - TRADING_DAYS).date()}):", OPT_INPUTS.risk_free_rate)
# Out:
# Optimization Date: 2024-11-04
# Risk-Free Rate (2024-11-01): 0.0461

# %%
OPT_INPUTS.run_full_pipeline()
# Out:
# ################################################################################
# # OPTIMIZER INPUTS FULL PIPELINE
# # Optimization Date: 2024-11-04
# # Assets: 10
# # Simulations: 250
# # Horizon: 21 days
# ################################################################################
#
# ================================================================================
# LOADING SIMULATORS FOR 10 ASSETS
# ================================================================================
# Optimization Date: 2024-11-04
# Model Date: 20241101
#   [1/10] Loading Technology Select Sector SPDR...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 OPT_INPUTS.run_full_pipeline()
#
# File ~/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/OPTIMIZER_INPUTS.py:930, in OPTIMIZER_INPUTS.run_full_pipeline(self, verbose)
#     927     print(f"{'#'*80}")
#     929 # Phase 1: Load and prepare
# --> 930 self.load_simulator_objects(verbose=verbose)
#     931 self.get_fwd_regime_probs()
#     932 self.estimate_regime_correlations(verbose=verbose)
#
# File ~/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/OPTIMIZER_INPUTS.py:175, in OPTIMIZER_INPUTS.load_simulator_objects(self, verbose)
#     172 km_model_path = self.ALL_KM_MODEL_PATHS[asset_idx]
#     173 kmrf_preds_path = self.ALL_KMRF_PREDICTION_PATHS[asset_idx]
# --> 175 sim = SIMULATOR(km_model_path=km_model_path, kmrf_preds_path=kmrf_preds_path)
#     176 sim.prepare_for_simulation()  # Run significance tests, fit distributions, compute transition matrix
#     178 self.simulator_objects[asset] = sim
#
# File ~/Desktop/Stevens MFE/Sem3/FE800/FE800_project_code/SIMULATOR.py:72, in SIMULATOR.__init__(self, km_model_path, kmrf_preds_path)
#      64 self.kmrf_predictions.index = pd.MultiIndex.from_arrays([
#      65     self.kmrf_predictions.index.get_level_values(0),
#      66     self.kmrf_predictions.index.get_level_values(1),
#    (...)     69     names=['date', 'horizon', 'prediction_date']
#      70 )
#      71 self.kmrf_predictions_int = self.kmrf_predictions.rename(columns=self.regime_to_int)
# ---> 72 self.regime_pred_rankings = self.kmrf_predictions.drop(columns=['model_end_date']).apply(lambda row: list(row.sort_values(ascending=False).index), axis=1).to_frame(name='regime_ranking')
#      73 self.regime_pred_rankings_int = self.regime_pred_rankings.apply(lambda row: [self.regime_to_int[regime] for regime in row['regime_ranking']], axis=1).to_frame(name='regime_ranking')
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/site-packages/pandas/core/frame.py:10401, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10387 from pandas.core.apply import frame_apply
#   10389 op = frame_apply(
#   10390     self,
#   10391     func=func,
#    (...)  10399     kwargs=kwargs,
#   10400 )
# > 10401 return op.apply().__finalize__(self, method="apply")
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/site-packages/pandas/core/apply.py:1079, in FrameApply.apply_series_generator(self)
#    1076 results = {}
#    1078 with option_context("mode.chained_assignment", None):
# -> 1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
#    1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/site-packages/pandas/core/apply.py:1267, in FrameColumnApply.series_generator(self)
#    1265 ser._mgr = mgr
#    1266 mgr.set_values(arr)
# -> 1267 object.__setattr__(ser, "_name", name)
#    1268 if not is_view:
#    1269     # In apply_series_generator we store the a shallow copy of the
#    1270     # result, which potentially increases the ref count of this reused
#    (...)   1273     # the refs here to avoid triggering a unnecessary CoW inside the
#    1274     # applied function (https://github.com/pandas-dev/pandas/pull/56212)
#    1275     mgr.blocks[0].refs = BlockValuesRefs(mgr.blocks[0])  # type: ignore[union-attr]
#
# KeyboardInterrupt:

# %%
OPT_INPUTS.optimize_portfolio(objective='max_sharpe', allow_short=True, gross_exposure=2)
# Out:
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 10
#   Short selling: Allowed
#   Gross exposure limit: 200.0%
#
#   Optimization Results:
#     Portfolio Return: 26.07%
#     Portfolio Risk: 15.90%
#     Sharpe Ratio: 1.350
#     Sortino Ratio: 0.000
#
#   Portfolio Weights:
#     Consumer Discretionary Select Sector SPDR:   80.28%
#     Technology Select Sector SPDR:   47.70%
#     iShares U.S. Real Estate ETF:   16.05%
#     Energy Select Sector SPDR:    4.40%
#     Financial Select Sector SPDR:    1.57%
#     Health Care Select Sector SPDR:  -22.86%
#     Materials Select Sector SPDR:  -27.14%
#
# ✓ Portfolio optimized
# ================================================================================

# %%
OPT_INPUTS.portfolio_summary()
# Out:
#                                            Weight  Expected Return  \
# Consumer Discretionary Select Sector SPDR  0.8028           0.2128
# Technology Select Sector SPDR               0.477           0.2157
# Materials Select Sector SPDR              -0.2714           0.0922
# Health Care Select Sector SPDR            -0.2286           0.0802
# iShares U.S. Real Estate ETF               0.1605           0.1375
# Energy Select Sector SPDR                   0.044           0.1313
# Financial Select Sector SPDR               0.0157           0.1577
# Industrial Select Sector SPDR                               0.1341
# Utilities Select Sector SPDR                                0.0746
# Consumer Staples Select Sector SPDR                         0.0946
#
#                                           Return Contribution  Marginal Risk  \
# Consumer Discretionary Select Sector SPDR              0.1708         0.1369
# Technology Select Sector SPDR                          0.1029         0.1390
# Materials Select Sector SPDR                           -0.025         0.0743
# Health Care Select Sector SPDR                        -0.0183         0.0655
# iShares U.S. Real Estate ETF                           0.0221         0.0811
# Energy Select Sector SPDR                              0.0058         0.0765
# Financial Select Sector SPDR                           0.0025         0.0960
# Industrial Select Sector SPDR                                         0.0941
# Utilities Select Sector SPDR                                          0.0438
# Consumer Staples Select Sector SPDR                                   0.0532
#
#                                           Risk Contribution  \
# Consumer Discretionary Select Sector SPDR            0.1099
# Technology Select Sector SPDR                        0.0663
# Materials Select Sector SPDR                        -0.0202
# Health Care Select Sector SPDR                       -0.015
# iShares U.S. Real Estate ETF                          0.013
# Energy Select Sector SPDR                            0.0034
# Financial Select Sector SPDR                         0.0015
# Industrial Select Sector SPDR
# Utilities Select Sector SPDR
# Consumer Staples Select Sector SPDR
#
#                                           Risk Contribution %
# Consumer Discretionary Select Sector SPDR              0.6913
# Technology Select Sector SPDR                          0.4172
# Materials Select Sector SPDR                          -0.1269
# Health Care Select Sector SPDR                        -0.0942
# iShares U.S. Real Estate ETF                           0.0819
# Energy Select Sector SPDR                              0.0212
# Financial Select Sector SPDR                           0.0095
# Industrial Select Sector SPDR
# Utilities Select Sector SPDR
# Consumer Staples Select Sector SPDR

# %%
OPT_INPUTS.plot_efficient_frontier()
# Out:
# (<Figure size 1000x700 with 1 Axes>,
#  <Axes: title={'center': 'Efficient Frontier'}, xlabel='Risk (Annualized Volatility)', ylabel='Expected Return (Annualized)'>)

# %%
OPT_INPUTS.market_simulator.kmrf_predictions
# Out:
#                                    model_end_date  P(LV_Bull)  P(LV_Bear)  \
# date       horizon prediction_date
# 2019-01-02 1       2019-01-02            20181231    0.005484    0.738907
#            2       2019-01-03            20181231    0.002844    0.772020
#            3       2019-01-04            20181231    0.003930    0.787103
#            4       2019-01-07            20181231    0.003230    0.802660
#            5       2019-01-08            20181231    0.002842    0.782096
# ...                                           ...         ...         ...
# 2025-10-31 17      2025-11-25            20251007    0.992879    0.001189
#            18      2025-11-26            20251007    0.991069    0.001485
#            19      2025-11-28            20251007    0.990190    0.001576
#            20      2025-12-01            20251007    0.992680    0.001024
#            21      2025-12-02            20251007    0.990339    0.001413
#
#                                     P(HV_Bull)  P(HV_Bear)
# date       horizon prediction_date
# 2019-01-02 1       2019-01-02         0.015601    0.240008
#            2       2019-01-03         0.009267    0.215869
#            3       2019-01-04         0.008758    0.200209
#            4       2019-01-07         0.007942    0.186167
#            5       2019-01-08         0.005851    0.209211
# ...                                        ...         ...
# 2025-10-31 17      2025-11-25         0.003100    0.002832
#            18      2025-11-26         0.003692    0.003754
#            19      2025-11-28         0.003913    0.004321
#            20      2025-12-01         0.002428    0.003867
#            21      2025-12-02         0.002538    0.005709
#
# [36099 rows x 5 columns]

# %% [markdown]
# #### --------------------------------------------------------

# %%
KM_MODEL_DATES = get_KM_model_dates()
get_asset_names()
# Out:
# 0     Consumer Discretionary Select Sector SPDR
# 1           Consumer Staples Select Sector SPDR
# 2                     Energy Select Sector SPDR
# 3                  Financial Select Sector SPDR
# 4                Health Care Select Sector SPDR
# 5                 Industrial Select Sector SPDR
# 6                        Invesco DB Agriculture
# 7                             Invesco QQQ Trust
# 8                  Materials Select Sector SPDR
# 9         SPDR Dow Jones Industrial Average ETF
# 10                             SPDR Gold Shares
# 11                             SPDR S&P 500 ETF
# 12                Technology Select Sector SPDR
# 13               United States Natural Gas Fund
# 14                       United States Oil Fund
# 15                 Utilities Select Sector SPDR
# 16          Vanguard FTSE Developed Markets ETF
# 17           Vanguard FTSE Emerging Markets ETF
# 18                     Vanguard FTSE Europe ETF
# 19                  iShares China Large-Cap ETF
# 20                       iShares MSCI India ETF
# 21                       iShares MSCI Japan ETF
# 22                        iShares Micro-Cap ETF
# 23                     iShares Russell 2000 ETF
# 24              iShares Russell 2000 Growth ETF
# 25               iShares Russell 2000 Value ETF
# 26                  iShares Russell Mid-Cap ETF
# 27                   iShares S&P 500 Growth ETF
# 28                    iShares S&P 500 Value ETF
# 29                         iShares Silver Trust
# 30                 iShares U.S. Real Estate ETF
# dtype: object

# %%
PORTFOLIO_ASSETS = ['SPDR S&P 500 ETF', 'iShares Russell 2000 ETF',
                    'Vanguard FTSE Developed Markets ETF', 'Vanguard FTSE Emerging Markets ETF',
                    'iShares U.S. Real Estate ETF', 'SPDR Gold Shares']
START = pd.Timestamp(KM_MODEL_DATES.iloc[0]) + TRADING_DAYS
# END = pd.Timestamp(KM_MODEL_DATES.iloc[-1])
END  = pd.Timestamp('2025-10-31')
print("start date:", START.date(), "\nend date:", END.date())
# Out:
# start date: 2019-01-02
# end date: 2025-10-31

# %%
bt = BACKTEST(backtest_start=START, backtest_end=END,
              asset_list=PORTFOLIO_ASSETS,
              rebalance_frequency='monthly',
              objective='max_sharpe', allow_short=False, gross_exposure=None,
              n_days=21, n_simulations=250, 
              initial_capital=100_000.0, transaction_cost_bps=0.0,
              use_regime_trigger=True, regime_change_threshold=0.25,
              max_intermediate_rebalances=4,
              random_seed=123)

# %%
# Run the backtest
bt.run_parallel(n_cpus=4,verbose=True)
# Out:
# ================================================================================
# RUNNING BACKTEST (PARALLEL MODE)
# ================================================================================
# Period: 2019-01-02 to 2025-10-31
# Assets: 6
# Standard Rebalances: 82
# Objective: max_sharpe
# Allow Short: False, Gross Exposure: None
# Regime Trigger: Enabled (threshold=0.25)
# Max Intermediate Rebalances per Period: 4
# Parallel Workers: 4
# ================================================================================
#
# [Parallel] Processing 82 periods with optimizations and regime triggers...
# [Parallel(n_jobs=4)]: Using backend LokyBackend with 4 concurrent workers.
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 13.40%
#     Portfolio Risk: 13.88%
#     Sharpe Ratio: 0.791
#     Sortino Ratio: 1.173
#
#   Portfolio Weights:
#     SPDR Gold Shares:   41.92%
#     iShares U.S. Real Estate ETF:   32.94%
#     iShares Russell 2000 ETF:   25.14%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 15.55%
#     Portfolio Risk: 13.94%
#     Sharpe Ratio: 0.943
#     Sortino Ratio: 1.382
#
#   Portfolio Weights:
#     Vanguard FTSE Emerging Markets ETF:   46.09%
#     SPDR Gold Shares:   41.44%
#     iShares Russell 2000 ETF:   12.47%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 13.22%
#     Portfolio Risk: 11.43%
#     Sharpe Ratio: 0.943
#     Sortino Ratio: 1.363
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   73.68%
#     SPDR Gold Shares:   23.44%
#     iShares U.S. Real Estate ETF:    2.88%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 15.00%
#     Portfolio Risk: 11.56%
#     Sharpe Ratio: 1.085
#     Sortino Ratio: 1.590
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   62.35%
#     SPDR Gold Shares:   37.65%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 18.01%
#     Portfolio Risk: 14.91%
#     Sharpe Ratio: 1.045
#     Sortino Ratio: 1.510
#
#   Portfolio Weights:
#     Vanguard FTSE Emerging Markets ETF:   68.41%
#     SPDR Gold Shares:   31.59%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 9.80%
#     Portfolio Risk: 13.56%
#     Sharpe Ratio: 0.543
#     Sortino Ratio: 0.768
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   45.49%
#     Vanguard FTSE Emerging Markets ETF:   35.03%
#     SPDR Gold Shares:   19.48%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.79%
#     Portfolio Risk: 16.34%
#     Sharpe Ratio: 0.940
#     Sortino Ratio: 1.388
#
#   Portfolio Weights:
#     Vanguard FTSE Emerging Markets ETF:   49.18%
#     iShares Russell 2000 ETF:   33.93%
#     SPDR Gold Shares:   16.89%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 10.21%
#     Portfolio Risk: 11.17%
#     Sharpe Ratio: 0.704
#     Sortino Ratio: 1.006
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   65.59%
#     iShares U.S. Real Estate ETF:   19.06%
#     SPDR Gold Shares:   15.35%
#
# ✓ Portfolio optimized
# ================================================================================
# [Parallel(n_jobs=4)]: Done   5 tasks      | elapsed:  5.9min
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.36%
#     Portfolio Risk: 18.23%
#     Sharpe Ratio: 0.819
#     Sortino Ratio: 1.151
#
#   Portfolio Weights:
#     Vanguard FTSE Emerging Markets ETF:  100.00%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 12.90%
#     Portfolio Risk: 11.23%
#     Sharpe Ratio: 0.952
#     Sortino Ratio: 1.379
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   61.24%
#     SPDR Gold Shares:   38.76%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 10.87%
#     Portfolio Risk: 11.38%
#     Sharpe Ratio: 0.774
#     Sortino Ratio: 1.119
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   71.06%
#     SPDR Gold Shares:   28.94%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.51%
#     Portfolio Risk: 12.64%
#     Sharpe Ratio: 1.149
#     Sortino Ratio: 1.690
#
#   Portfolio Weights:
#     SPDR Gold Shares:   62.09%
#     SPDR S&P 500 ETF:   37.91%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 10.46%
#     Portfolio Risk: 13.58%
#     Sharpe Ratio: 0.638
#     Sortino Ratio: 0.911
#
#   Portfolio Weights:
#     SPDR Gold Shares:   70.90%
#     SPDR S&P 500 ETF:   29.10%
#
# ✓ Portfolio optimized
# ================================================================================
# [Parallel(n_jobs=4)]: Done  10 tasks      | elapsed: 11.1min
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.93%
#     Portfolio Risk: 11.38%
#     Sharpe Ratio: 1.352
#     Sortino Ratio: 2.014
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   60.06%
#     SPDR Gold Shares:   38.86%
#     Vanguard FTSE Emerging Markets ETF:    1.08%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.19%
#     Portfolio Risk: 11.72%
#     Sharpe Ratio: 1.330
#     Sortino Ratio: 1.965
#
#   Portfolio Weights:
#     SPDR Gold Shares:   42.94%
#     SPDR S&P 500 ETF:   37.14%
#     Vanguard FTSE Emerging Markets ETF:   15.87%
#     iShares U.S. Real Estate ETF:    4.04%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 24.65%
#     Portfolio Risk: 17.19%
#     Sharpe Ratio: 1.345
#     Sortino Ratio: 1.965
#
#   Portfolio Weights:
#     Vanguard FTSE Emerging Markets ETF:   96.10%
#     SPDR S&P 500 ETF:    3.90%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 21.87%
#     Portfolio Risk: 17.55%
#     Sharpe Ratio: 1.241
#     Sortino Ratio: 1.821
#
#   Portfolio Weights:
#     SPDR Gold Shares:  100.00%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.21%
#     Portfolio Risk: 13.16%
#     Sharpe Ratio: 1.177
#     Sortino Ratio: 1.694
#
#   Portfolio Weights:
#     SPDR Gold Shares:   49.23%
#     Vanguard FTSE Developed Markets ETF:   25.70%
#     iShares U.S. Real Estate ETF:   25.07%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 22.11%
#     Portfolio Risk: 17.49%
#     Sharpe Ratio: 1.256
#     Sortino Ratio: 1.820
#
#   Portfolio Weights:
#     SPDR Gold Shares:  100.00%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 7.61%
#     Portfolio Risk: 14.32%
#     Sharpe Ratio: 0.522
#     Sortino Ratio: 0.742
#
#   Portfolio Weights:
#     SPDR Gold Shares:   50.67%
#     SPDR S&P 500 ETF:   49.33%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 15.18%
#     Portfolio Risk: 11.48%
#     Sharpe Ratio: 1.186
#     Sortino Ratio: 1.763
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   55.94%
#     SPDR Gold Shares:   44.06%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 24.24%
#     Portfolio Risk: 13.89%
#     Sharpe Ratio: 1.653
#     Sortino Ratio: 2.401
#
#   Portfolio Weights:
#     SPDR Gold Shares:   87.14%
#     Vanguard FTSE Developed Markets ETF:   12.01%
#     iShares Russell 2000 ETF:    0.85%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.50%
#     Portfolio Risk: 14.72%
#     Sharpe Ratio: 1.179
#     Sortino Ratio: 1.738
#
#   Portfolio Weights:
#     SPDR Gold Shares:   76.15%
#     SPDR S&P 500 ETF:   17.12%
#     iShares U.S. Real Estate ETF:    6.73%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 18.63%
#     Portfolio Risk: 14.65%
#     Sharpe Ratio: 1.229
#     Sortino Ratio: 1.839
#
#   Portfolio Weights:
#     SPDR Gold Shares:   63.73%
#     iShares Russell 2000 ETF:   34.31%
#     iShares U.S. Real Estate ETF:    1.96%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 11.72%
#     Portfolio Risk: 13.14%
#     Sharpe Ratio: 0.883
#     Sortino Ratio: 1.288
#
#   Portfolio Weights:
#     SPDR Gold Shares:   51.79%
#     SPDR S&P 500 ETF:   48.21%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 21.88%
#     Portfolio Risk: 17.14%
#     Sharpe Ratio: 1.250
#     Sortino Ratio: 1.878
#
#   Portfolio Weights:
#     SPDR Gold Shares:  100.00%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 19.19%
#     Portfolio Risk: 12.96%
#     Sharpe Ratio: 1.471
#     Sortino Ratio: 2.177
#
#   Portfolio Weights:
#     SPDR Gold Shares:   59.46%
#     SPDR S&P 500 ETF:   40.54%
#
# ✓ Portfolio optimized
# ================================================================================
# [Parallel(n_jobs=4)]: Done  17 tasks      | elapsed: 18.6min
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.57%
#     Portfolio Risk: 11.90%
#     Sharpe Ratio: 1.379
#     Sortino Ratio: 2.028
#
#   Portfolio Weights:
#     SPDR Gold Shares:   48.03%
#     SPDR S&P 500 ETF:   30.45%
#     iShares U.S. Real Estate ETF:   21.52%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.34%
#     Portfolio Risk: 17.91%
#     Sharpe Ratio: 0.905
#     Sortino Ratio: 1.300
#
#   Portfolio Weights:
#     SPDR Gold Shares:  100.00%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 13.01%
#     Portfolio Risk: 13.69%
#     Sharpe Ratio: 0.926
#     Sortino Ratio: 1.343
#
#   Portfolio Weights:
#     SPDR Gold Shares:   57.12%
#     iShares U.S. Real Estate ETF:   28.97%
#     Vanguard FTSE Developed Markets ETF:   13.91%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.21%
#     Portfolio Risk: 12.76%
#     Sharpe Ratio: 1.336
#     Sortino Ratio: 1.993
#
#   Portfolio Weights:
#     SPDR Gold Shares:   57.88%
#     SPDR S&P 500 ETF:   42.12%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: -0.23%
#     Portfolio Risk: 29.41%
#     Sharpe Ratio: -0.013
#     Sortino Ratio: -0.016
#
#   Portfolio Weights:
#     Vanguard FTSE Emerging Markets ETF:  100.00%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 19.79%
#     Portfolio Risk: 13.55%
#     Sharpe Ratio: 1.451
#     Sortino Ratio: 2.195
#
#   Portfolio Weights:
#     SPDR Gold Shares:   53.24%
#     SPDR S&P 500 ETF:   46.76%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.09%
#     Portfolio Risk: 16.06%
#     Sharpe Ratio: 1.037
#     Sortino Ratio: 1.528
#
#   Portfolio Weights:
#     SPDR Gold Shares:   81.38%
#     Vanguard FTSE Developed Markets ETF:   12.96%
#     iShares U.S. Real Estate ETF:    3.05%
#     Vanguard FTSE Emerging Markets ETF:    2.62%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.56%
#     Portfolio Risk: 12.49%
#     Sharpe Ratio: 1.396
#     Sortino Ratio: 2.057
#
#   Portfolio Weights:
#     SPDR Gold Shares:   63.14%
#     SPDR S&P 500 ETF:   36.86%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 12.35%
#     Portfolio Risk: 11.42%
#     Sharpe Ratio: 1.073
#     Sortino Ratio: 1.576
#
#   Portfolio Weights:
#     SPDR Gold Shares:   40.07%
#     SPDR S&P 500 ETF:   39.82%
#     iShares U.S. Real Estate ETF:   11.85%
#     Vanguard FTSE Emerging Markets ETF:    8.26%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 22.69%
#     Portfolio Risk: 14.65%
#     Sharpe Ratio: 1.543
#     Sortino Ratio: 2.267
#
#   Portfolio Weights:
#     iShares U.S. Real Estate ETF:   62.19%
#     SPDR Gold Shares:   33.05%
#     Vanguard FTSE Emerging Markets ETF:    4.76%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 11.63%
#     Portfolio Risk: 11.41%
#     Sharpe Ratio: 1.011
#     Sortino Ratio: 1.457
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   67.23%
#     SPDR Gold Shares:   20.31%
#     iShares U.S. Real Estate ETF:   12.46%
#
# ✓ Portfolio optimized
# ================================================================================
# [Parallel(n_jobs=4)]: Done  24 tasks      | elapsed: 25.6min
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 10.25%
#     Portfolio Risk: 11.14%
#     Sharpe Ratio: 0.911
#     Sortino Ratio: 1.318
#
#   Portfolio Weights:
#     SPDR Gold Shares:   43.28%
#     SPDR S&P 500 ETF:   39.13%
#     iShares U.S. Real Estate ETF:   17.59%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.69%
#     Portfolio Risk: 10.78%
#     Sharpe Ratio: 1.639
#     Sortino Ratio: 2.419
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   53.79%
#     SPDR Gold Shares:   40.77%
#     iShares U.S. Real Estate ETF:    5.44%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 19.01%
#     Portfolio Risk: 14.43%
#     Sharpe Ratio: 1.312
#     Sortino Ratio: 1.938
#
#   Portfolio Weights:
#     SPDR Gold Shares:   51.42%
#     Vanguard FTSE Emerging Markets ETF:   48.58%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 11.58%
#     Portfolio Risk: 12.22%
#     Sharpe Ratio: 0.946
#     Sortino Ratio: 1.365
#
#   Portfolio Weights:
#     SPDR Gold Shares:   57.05%
#     iShares U.S. Real Estate ETF:   32.86%
#     SPDR S&P 500 ETF:   10.09%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 20.73%
#     Portfolio Risk: 13.39%
#     Sharpe Ratio: 1.547
#     Sortino Ratio: 2.282
#
#   Portfolio Weights:
#     Vanguard FTSE Emerging Markets ETF:   44.74%
#     SPDR S&P 500 ETF:   29.73%
#     SPDR Gold Shares:   25.53%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 15.66%
#     Portfolio Risk: 14.93%
#     Sharpe Ratio: 1.045
#     Sortino Ratio: 1.538
#
#   Portfolio Weights:
#     SPDR Gold Shares:   60.37%
#     Vanguard FTSE Emerging Markets ETF:   39.63%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 15.34%
#     Portfolio Risk: 11.05%
#     Sharpe Ratio: 1.384
#     Sortino Ratio: 2.033
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   62.44%
#     SPDR Gold Shares:   29.78%
#     iShares U.S. Real Estate ETF:    5.57%
#     Vanguard FTSE Emerging Markets ETF:    2.22%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 11.38%
#     Portfolio Risk: 11.19%
#     Sharpe Ratio: 1.013
#     Sortino Ratio: 1.439
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   61.06%
#     SPDR Gold Shares:   38.94%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 10.38%
#     Portfolio Risk: 10.82%
#     Sharpe Ratio: 0.955
#     Sortino Ratio: 1.377
#
#   Portfolio Weights:
#     SPDR Gold Shares:   42.45%
#     iShares U.S. Real Estate ETF:   31.18%
#     SPDR S&P 500 ETF:   26.38%
#
# ✓ Portfolio optimized
# ================================================================================
# [Parallel(n_jobs=4)]: Done  33 tasks      | elapsed: 52.3min
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 11.22%
#     Portfolio Risk: 11.15%
#     Sharpe Ratio: 1.004
#     Sortino Ratio: 1.446
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   64.89%
#     SPDR Gold Shares:   35.11%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 31.92%
#     Portfolio Risk: 13.06%
#     Sharpe Ratio: 2.440
#     Sortino Ratio: 3.769
#
#   Portfolio Weights:
#     Vanguard FTSE Emerging Markets ETF:   45.90%
#     SPDR S&P 500 ETF:   35.07%
#     SPDR Gold Shares:   19.03%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.65%
#     Portfolio Risk: 10.65%
#     Sharpe Ratio: 1.559
#     Sortino Ratio: 2.305
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   38.80%
#     SPDR Gold Shares:   32.97%
#     iShares U.S. Real Estate ETF:   28.24%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 19.34%
#     Portfolio Risk: 11.51%
#     Sharpe Ratio: 1.674
#     Sortino Ratio: 2.521
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   40.05%
#     SPDR Gold Shares:   27.52%
#     Vanguard FTSE Developed Markets ETF:   20.32%
#     iShares U.S. Real Estate ETF:   12.11%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.89%
#     Portfolio Risk: 11.14%
#     Sharpe Ratio: 1.601
#     Sortino Ratio: 2.348
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   60.91%
#     SPDR Gold Shares:   39.09%
#
# ✓ Portfolio optimized
# ================================================================================
# [Parallel(n_jobs=4)]: Done  42 tasks      | elapsed: 61.1min
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 22.68%
#     Portfolio Risk: 13.93%
#     Sharpe Ratio: 1.601
#     Sortino Ratio: 2.422
#
#   Portfolio Weights:
#     SPDR Gold Shares:   43.69%
#     Vanguard FTSE Developed Markets ETF:   41.76%
#     iShares Russell 2000 ETF:    9.03%
#     SPDR S&P 500 ETF:    5.52%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 14.52%
#     Portfolio Risk: 17.38%
#     Sharpe Ratio: 0.592
#     Sortino Ratio: 0.869
#
#   Portfolio Weights:
#     iShares U.S. Real Estate ETF:   50.13%
#     SPDR S&P 500 ETF:   49.87%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 13.26%
#     Portfolio Risk: 11.67%
#     Sharpe Ratio: 1.090
#     Sortino Ratio: 1.581
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   53.06%
#     SPDR Gold Shares:   38.05%
#     Vanguard FTSE Developed Markets ETF:    8.89%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 18.14%
#     Portfolio Risk: 13.49%
#     Sharpe Ratio: 1.024
#     Sortino Ratio: 1.510
#
#   Portfolio Weights:
#     iShares U.S. Real Estate ETF:   57.57%
#     SPDR Gold Shares:   42.43%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 14.05%
#     Portfolio Risk: 12.76%
#     Sharpe Ratio: 0.746
#     Sortino Ratio: 1.099
#
#   Portfolio Weights:
#     SPDR Gold Shares:   60.24%
#     iShares U.S. Real Estate ETF:   29.51%
#     iShares Russell 2000 ETF:   10.25%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 15.99%
#     Portfolio Risk: 12.87%
#     Sharpe Ratio: 1.213
#     Sortino Ratio: 1.780
#
#   Portfolio Weights:
#     SPDR Gold Shares:   66.07%
#     Vanguard FTSE Developed Markets ETF:   20.72%
#     iShares U.S. Real Estate ETF:   13.21%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 13.06%
#     Portfolio Risk: 14.31%
#     Sharpe Ratio: 0.882
#     Sortino Ratio: 1.299
#
#   Portfolio Weights:
#     iShares Russell 2000 ETF:   51.88%
#     SPDR Gold Shares:   46.38%
#     SPDR S&P 500 ETF:    1.75%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.31%
#     Portfolio Risk: 13.12%
#     Sharpe Ratio: 0.911
#     Sortino Ratio: 1.336
#
#   Portfolio Weights:
#     iShares U.S. Real Estate ETF:   40.83%
#     SPDR Gold Shares:   33.20%
#     SPDR S&P 500 ETF:   25.97%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.20%
#     Portfolio Risk: 13.14%
#     Sharpe Ratio: 0.858
#     Sortino Ratio: 1.274
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   49.10%
#     iShares U.S. Real Estate ETF:   25.96%
#     SPDR Gold Shares:   24.93%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 20.33%
#     Portfolio Risk: 15.08%
#     Sharpe Ratio: 1.320
#     Sortino Ratio: 1.929
#
#   Portfolio Weights:
#     SPDR Gold Shares:   85.65%
#     Vanguard FTSE Developed Markets ETF:   14.35%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 15.08%
#     Portfolio Risk: 11.75%
#     Sharpe Ratio: 0.887
#     Sortino Ratio: 1.302
#
#   Portfolio Weights:
#     SPDR Gold Shares:   41.32%
#     iShares U.S. Real Estate ETF:   29.97%
#     SPDR S&P 500 ETF:   28.71%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 14.49%
#     Portfolio Risk: 12.87%
#     Sharpe Ratio: 0.793
#     Sortino Ratio: 1.163
#
#   Portfolio Weights:
#     SPDR Gold Shares:   52.88%
#     iShares U.S. Real Estate ETF:   47.12%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 19.74%
#     Portfolio Risk: 17.36%
#     Sharpe Ratio: 0.864
#     Sortino Ratio: 1.280
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   50.18%
#     iShares U.S. Real Estate ETF:   41.40%
#     iShares Russell 2000 ETF:    8.42%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 15.03%
#     Portfolio Risk: 11.56%
#     Sharpe Ratio: 1.254
#     Sortino Ratio: 1.851
#
#   Portfolio Weights:
#     iShares U.S. Real Estate ETF:   62.19%
#     SPDR Gold Shares:   35.09%
#     iShares Russell 2000 ETF:    2.72%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 20.08%
#     Portfolio Risk: 14.21%
#     Sharpe Ratio: 1.076
#     Sortino Ratio: 1.625
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   66.37%
#     SPDR Gold Shares:   16.87%
#     iShares U.S. Real Estate ETF:   16.75%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 11.83%
#     Portfolio Risk: 12.57%
#     Sharpe Ratio: 0.553
#     Sortino Ratio: 0.804
#
#   Portfolio Weights:
#     SPDR Gold Shares:   46.74%
#     iShares U.S. Real Estate ETF:   33.62%
#     SPDR S&P 500 ETF:   19.64%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 18.18%
#     Portfolio Risk: 16.94%
#     Sharpe Ratio: 0.762
#     Sortino Ratio: 1.133
#
#   Portfolio Weights:
#     iShares Russell 2000 ETF:   68.24%
#     SPDR Gold Shares:   31.76%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 26.12%
#     Portfolio Risk: 17.02%
#     Sharpe Ratio: 1.235
#     Sortino Ratio: 1.800
#
#   Portfolio Weights:
#     SPDR Gold Shares:  100.00%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.12%
#     Portfolio Risk: 13.44%
#     Sharpe Ratio: 0.915
#     Sortino Ratio: 1.376
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   91.52%
#     SPDR Gold Shares:    8.48%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.07%
#     Portfolio Risk: 11.78%
#     Sharpe Ratio: 0.985
#     Sortino Ratio: 1.450
#
#   Portfolio Weights:
#     SPDR Gold Shares:   58.22%
#     SPDR S&P 500 ETF:   27.88%
#     iShares U.S. Real Estate ETF:   13.91%
#
# ✓ Portfolio optimized
# ================================================================================
# [Parallel(n_jobs=4)]: Done  53 tasks      | elapsed: 128.6min
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.70%
#     Portfolio Risk: 13.41%
#     Sharpe Ratio: 0.885
#     Sortino Ratio: 1.330
#
#   Portfolio Weights:
#     SPDR Gold Shares:   45.15%
#     SPDR S&P 500 ETF:   30.81%
#     iShares U.S. Real Estate ETF:    9.67%
#     Vanguard FTSE Emerging Markets ETF:    9.04%
#     iShares Russell 2000 ETF:    5.32%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.82%
#     Portfolio Risk: 11.94%
#     Sharpe Ratio: 0.952
#     Sortino Ratio: 1.400
#
#   Portfolio Weights:
#     SPDR Gold Shares:   44.95%
#     iShares U.S. Real Estate ETF:   31.53%
#     SPDR S&P 500 ETF:   23.52%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.21%
#     Portfolio Risk: 16.40%
#     Sharpe Ratio: 0.646
#     Sortino Ratio: 0.961
#
#   Portfolio Weights:
#     iShares Russell 2000 ETF:   63.74%
#     SPDR Gold Shares:   36.26%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 10.57%
#     Portfolio Risk: 13.98%
#     Sharpe Ratio: 0.359
#     Sortino Ratio: 0.506
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:  100.00%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 18.00%
#     Portfolio Risk: 16.02%
#     Sharpe Ratio: 0.778
#     Sortino Ratio: 1.115
#
#   Portfolio Weights:
#     iShares U.S. Real Estate ETF:   66.04%
#     SPDR S&P 500 ETF:   33.96%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 27.04%
#     Portfolio Risk: 15.77%
#     Sharpe Ratio: 1.364
#     Sortino Ratio: 2.074
#
#   Portfolio Weights:
#     iShares Russell 2000 ETF:   66.68%
#     SPDR Gold Shares:   33.32%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
# ...
#     Sharpe Ratio: 0.558
#     Sortino Ratio: 0.823
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   57.15%
#     SPDR Gold Shares:   42.85%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.30%
#     Portfolio Risk: 10.47%
#     Sharpe Ratio: 1.038
#     Sortino Ratio: 1.545
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   49.65%
#     SPDR Gold Shares:   34.80%
#     iShares U.S. Real Estate ETF:    8.59%
#     Vanguard FTSE Emerging Markets ETF:    6.97%
#
# ✓ Portfolio optimized
# ================================================================================
# [Parallel(n_jobs=4)]: Done  64 tasks      | elapsed: 142.5min
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 13.90%
#     Portfolio Risk: 11.29%
#     Sharpe Ratio: 0.748
#     Sortino Ratio: 1.101
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   54.15%
#     SPDR Gold Shares:   33.12%
#     Vanguard FTSE Emerging Markets ETF:   12.74%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 18.36%
#     Portfolio Risk: 13.07%
#     Sharpe Ratio: 0.983
#     Sortino Ratio: 1.429
#
#   Portfolio Weights:
#     Vanguard FTSE Emerging Markets ETF:   48.48%
#     SPDR S&P 500 ETF:   23.34%
#     SPDR Gold Shares:   16.68%
#     iShares U.S. Real Estate ETF:   11.51%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.71%
#     Portfolio Risk: 11.37%
#     Sharpe Ratio: 1.000
#     Sortino Ratio: 1.498
#
#   Portfolio Weights:
#     SPDR Gold Shares:   55.35%
#     SPDR S&P 500 ETF:   44.65%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 13.86%
#     Portfolio Risk: 11.95%
#     Sharpe Ratio: 0.703
#     Sortino Ratio: 1.022
#
#   Portfolio Weights:
#     SPDR Gold Shares:   56.41%
#     SPDR S&P 500 ETF:   36.95%
#     Vanguard FTSE Emerging Markets ETF:    6.64%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 11.91%
#     Portfolio Risk: 11.22%
#     Sharpe Ratio: 0.603
#     Sortino Ratio: 0.875
#
#   Portfolio Weights:
#     SPDR Gold Shares:   52.21%
#     SPDR S&P 500 ETF:   47.79%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 9.87%
#     Portfolio Risk: 12.16%
#     Sharpe Ratio: 0.423
#     Sortino Ratio: 0.605
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   55.67%
#     Vanguard FTSE Emerging Markets ETF:   26.90%
#     SPDR Gold Shares:   17.43%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 13.34%
#     Portfolio Risk: 10.97%
#     Sharpe Ratio: 0.792
#     Sortino Ratio: 1.143
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   70.66%
#     SPDR Gold Shares:   29.34%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 19.14%
#     Portfolio Risk: 10.86%
#     Sharpe Ratio: 1.351
#     Sortino Ratio: 2.040
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   44.60%
#     SPDR Gold Shares:   36.49%
#     Vanguard FTSE Emerging Markets ETF:   12.92%
#     iShares U.S. Real Estate ETF:    5.98%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.84%
#     Portfolio Risk: 11.83%
#     Sharpe Ratio: 1.055
#     Sortino Ratio: 1.566
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   50.71%
#     SPDR Gold Shares:   30.69%
#     iShares Russell 2000 ETF:   18.60%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 18.22%
#     Portfolio Risk: 10.86%
#     Sharpe Ratio: 1.278
#     Sortino Ratio: 1.918
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   51.68%
#     SPDR Gold Shares:   48.32%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 11.03%
#     Portfolio Risk: 16.36%
#     Sharpe Ratio: 0.411
#     Sortino Ratio: 0.589
#
#   Portfolio Weights:
#     SPDR Gold Shares:  100.00%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 18.62%
#     Portfolio Risk: 13.19%
#     Sharpe Ratio: 1.085
#     Sortino Ratio: 1.615
#
#   Portfolio Weights:
#     SPDR Gold Shares:   66.29%
#     iShares U.S. Real Estate ETF:   26.33%
#     iShares Russell 2000 ETF:    7.37%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 18.56%
#     Portfolio Risk: 13.99%
#     Sharpe Ratio: 1.016
#     Sortino Ratio: 1.530
#
#   Portfolio Weights:
#     SPDR Gold Shares:   57.73%
#     iShares Russell 2000 ETF:   42.27%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 10.21%
#     Portfolio Risk: 12.40%
#     Sharpe Ratio: 0.474
#     Sortino Ratio: 0.691
#
#   Portfolio Weights:
#     SPDR Gold Shares:   66.53%
#     SPDR S&P 500 ETF:   33.47%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 21.05%
#     Portfolio Risk: 12.79%
#     Sharpe Ratio: 1.307
#     Sortino Ratio: 1.990
#
#   Portfolio Weights:
#     SPDR Gold Shares:   46.74%
#     iShares U.S. Real Estate ETF:   27.75%
#     iShares Russell 2000 ETF:   25.52%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 23.60%
#     Portfolio Risk: 15.11%
#     Sharpe Ratio: 1.276
#     Sortino Ratio: 1.906
#
#   Portfolio Weights:
#     iShares U.S. Real Estate ETF:   78.77%
#     SPDR Gold Shares:   21.23%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 21.45%
#     Portfolio Risk: 13.95%
#     Sharpe Ratio: 1.227
#     Sortino Ratio: 1.868
#
#   Portfolio Weights:
#     SPDR Gold Shares:   52.39%
#     iShares Russell 2000 ETF:   29.57%
#     SPDR S&P 500 ETF:   18.04%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.45%
#     Portfolio Risk: 11.58%
#     Sharpe Ratio: 1.037
#     Sortino Ratio: 1.512
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   76.81%
#     SPDR Gold Shares:   20.11%
#     Vanguard FTSE Emerging Markets ETF:    3.08%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 12.06%
#     Portfolio Risk: 14.31%
#     Sharpe Ratio: 0.535
#     Sortino Ratio: 0.775
#
#   Portfolio Weights:
#     SPDR Gold Shares:   64.18%
#     iShares Russell 2000 ETF:   35.82%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.40%
#     Portfolio Risk: 10.51%
#     Sharpe Ratio: 1.235
#     Sortino Ratio: 1.824
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   36.27%
#     SPDR Gold Shares:   36.22%
#     iShares U.S. Real Estate ETF:   27.51%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 17.69%
#     Portfolio Risk: 11.25%
#     Sharpe Ratio: 1.188
#     Sortino Ratio: 1.776
#
#   Portfolio Weights:
#     SPDR Gold Shares:   50.18%
#     SPDR S&P 500 ETF:   46.25%
#     Vanguard FTSE Emerging Markets ETF:    3.58%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 16.68%
#     Portfolio Risk: 11.83%
#     Sharpe Ratio: 1.063
#     Sortino Ratio: 1.557
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   51.74%
#     Vanguard FTSE Emerging Markets ETF:   26.36%
#     SPDR Gold Shares:   21.90%
#
# ✓ Portfolio optimized
# ================================================================================
#
# ================================================================================
# PORTFOLIO OPTIMIZATION
# ================================================================================
#   Objective: max_sharpe
#   Assets: 6
#   Short selling: Not allowed
#
#   Optimization Results:
#     Portfolio Return: 12.78%
#     Portfolio Risk: 10.91%
#     Sharpe Ratio: 0.804
#     Sortino Ratio: 1.151
#
#   Portfolio Weights:
#     SPDR S&P 500 ETF:   61.85%
#     SPDR Gold Shares:   19.95%
#     iShares U.S. Real Estate ETF:   18.20%
#
# ✓ Portfolio optimized
# ================================================================================
# [Parallel(n_jobs=4)]: Done  82 out of  82 | elapsed: 253.1min finished
#   Periods complete: 72/82 successful
#   Total triggered rebalances: 35
#
# [Sequential] Computing portfolio values...
#
# ================================================================================
# COMPILING RESULTS
# ================================================================================
#
#   Standard rebalances: 82
#   Triggered rebalances: 35
#   Total transaction costs: $0.00
#
# ✓ Backtest complete!
#
# ============================================================
# BACKTEST PERFORMANCE SUMMARY
# ============================================================
# Period:             2019-01-02 to 2025-10-31
# Trading Days:       1509
# Standard Rebalances: 82
# Triggered Rebalances: 25
# Total Rebalances:   107
# ------------------------------------------------------------
# Initial Capital:    $100,000.00
# Final Value:        $246,601.97
# Total Return:       146.60%
# Annualized Return:  16.27%
# Annualized Vol:     13.16%
# ------------------------------------------------------------
# Sharpe Ratio:       1.017
# Sortino Ratio:      1.382
# Max Drawdown:       -19.85%
# Win Rate:           57.4%
# ============================================================

# %%
# Print performance summary
bt.print_summary()
# Out:
# ============================================================
# BACKTEST PERFORMANCE SUMMARY
# ============================================================
# Period:             2019-01-02 to 2025-10-31
# Trading Days:       1509
# Standard Rebalances: 82
# Triggered Rebalances: 25
# Total Rebalances:   107
# ------------------------------------------------------------
# Initial Capital:    $100,000.00
# Final Value:        $246,601.97
# Total Return:       146.60%
# Annualized Return:  16.27%
# Annualized Vol:     13.16%
# ------------------------------------------------------------
# Sharpe Ratio:       1.017
# Sortino Ratio:      1.382
# Max Drawdown:       -19.85%
# Win Rate:           57.4%
# ============================================================

# %%
bt.returns
# Out:
# date
# 2019-01-02   -0.005416
# 2019-01-03    0.001413
# 2019-01-04    0.009527
# 2019-01-07    0.009160
# 2019-01-08    0.008709
#                 ...
# 2025-10-27    0.002355
# 2025-10-28   -0.003611
# 2025-10-29   -0.005063
# 2025-10-30   -0.002129
# 2025-10-31    0.001485
# Name: return, Length: 1509, dtype: float64

# %%
bt.get_benchmark_returns()
# Out:
# {'S&P 500': date
#  2019-01-02    0.001040
#  2019-01-03   -0.023863
#  2019-01-04    0.033496
#  2019-01-07    0.007885
#  2019-01-08    0.009395
#                  ...
#  2025-10-27    0.011798
#  2025-10-28    0.002656
#  2025-10-29    0.000480
#  2025-10-30   -0.010998
#  2025-10-31    0.003280
#  Name: SPDR S&P 500 ETF, Length: 1509, dtype: float64,
#  'MV Long-Only': date
#  2019-01-02    0.001040
#  2019-01-03   -0.023863
#  2019-01-04    0.033496
#  2019-01-07    0.007885
#  2019-01-08    0.009395
#                  ...
#  2025-10-27   -0.017611
#  2025-10-28   -0.004631
#  2025-10-29   -0.002686
#  2025-10-30    0.011735
#  2025-10-31   -0.003183
#  Length: 1509, dtype: float64}

# %%
# Plot cumulative returns vs benchmarks
bt.plot_performance()

# %%
# View weights history at each rebalance
print("Portfolio Weights at Each Rebalance:")
display(bt.weights_history)
# Out:
# Portfolio Weights at Each Rebalance:
#             SPDR S&P 500 ETF  iShares Russell 2000 ETF  \
# date
# 2019-01-02      1.731720e-16              2.514109e-01
# 2019-02-01      0.000000e+00              1.247305e-01
# 2019-02-07      4.255011e-17              0.000000e+00
# 2019-02-08      0.000000e+00              3.392911e-01
# 2019-02-14      0.000000e+00              0.000000e+00
# ...                      ...                       ...
# 2025-06-09      7.680888e-01              0.000000e+00
# 2025-07-10      3.627242e-01              1.971556e-16
# 2025-08-08      4.624852e-01              0.000000e+00
# 2025-09-09      5.174192e-01              1.862939e-16
# 2025-10-08      6.185286e-01              5.681925e-16
#
#             Vanguard FTSE Developed Markets ETF  \
# date
# 2019-01-02                         0.000000e+00
# 2019-02-01                         3.262239e-16
# 2019-02-07                         1.370761e-18
# 2019-02-08                         0.000000e+00
# 2019-02-14                         0.000000e+00
# ...                                         ...
# 2025-06-09                         0.000000e+00
# 2025-07-10                         0.000000e+00
# 2025-08-08                         0.000000e+00
# 2025-09-09                         0.000000e+00
# 2025-10-08                         1.609211e-15
#
#             Vanguard FTSE Emerging Markets ETF  iShares U.S. Real Estate ETF  \
# date
# 2019-01-02                        0.000000e+00                  3.293676e-01
# 2019-02-01                        4.609133e-01                  0.000000e+00
# 2019-02-07                        6.841030e-01                  0.000000e+00
# 2019-02-08                        4.917855e-01                  1.492846e-16
# 2019-02-14                        1.000000e+00                  0.000000e+00
# ...                                        ...                           ...
# 2025-06-09                        3.082035e-02                  7.979584e-16
# 2025-07-10                        0.000000e+00                  2.750972e-01
# 2025-08-08                        3.575797e-02                  0.000000e+00
# 2025-09-09                        2.636136e-01                  0.000000e+00
# 2025-10-08                        3.336656e-16                  1.819627e-01
#
#             SPDR Gold Shares
# date
# 2019-01-02          0.419221
# 2019-02-01          0.414356
# 2019-02-07          0.315897
# 2019-02-08          0.168923
# 2019-02-14          0.000000
# ...                      ...
# 2025-06-09          0.201091
# 2025-07-10          0.362179
# 2025-08-08          0.501757
# 2025-09-09          0.218967
# 2025-10-08          0.199509
#
# [107 rows x 6 columns]

# %%
# View rebalance types (standard vs triggered)
print("Rebalance Types:")
display(bt._rebalance_types)
# Out:
# Rebalance Types:
# date
# 2024-11-04     standard
# 2024-12-04     standard
# 2025-01-06     standard
# 2025-02-06     standard
# 2025-03-10     standard
# 2025-03-17    triggered
# 2025-04-08     standard
# 2025-04-25    triggered
# 2025-05-02    triggered
# 2025-05-05    triggered
# 2025-05-08     standard
# 2025-05-13    triggered
# 2025-06-09     standard
# 2025-07-10     standard
# 2025-08-08     standard
# 2025-09-09     standard
# 2025-10-08     standard
# Name: rebal_type, dtype: object

# %%
# Plot detailed analysis (drawdowns, rolling Sharpe, return distribution, weights)
bt.plot_detailed_analysis()

# %%
# Get performance metrics comparison
metrics_df = bt.get_metrics()
print("Performance Metrics Comparison:")
display(metrics_df)
# Out:
# Performance Metrics Comparison:
#                        Regime Strategy    S&P 500  MV Long-Only
# Total Return                  1.479450   1.544315      1.110389
# Annualized Return             0.163742   0.168771      0.132838
# Annualized Volatility         0.131584   0.196496      0.145146
# Sharpe Ratio                  1.024923   0.711940      0.716251
# Sortino Ratio                 1.393219   0.845770      0.965929
# Max Drawdown                 -0.198524  -0.341047     -0.177866
# Calmar Ratio                  0.824796   0.494862      0.746844
# Win Rate                      0.573890   0.563287      0.563950
# Avg Daily Return              0.000633   0.000697      0.000538
# Skewness                      0.013832  -0.285009     -0.133269
# Kurtosis                      5.997142  16.368733      4.806723
# N Rebalances                107.000000   0.000000     82.000000

# %%
# save the backtest object to a pickle file in backtests_v2/
filepath = f'backtests_v2/gen_gross-1_{START.strftime("%Y%m%d")}-{END.strftime("%Y%m%d")}.pkl'
with open(filepath, 'wb') as f:
    pickle.dump(bt, f)
